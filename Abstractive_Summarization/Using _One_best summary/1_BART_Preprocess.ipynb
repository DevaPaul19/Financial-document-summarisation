# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # New Section

# %%
# %cd /content/drive/MyDrive/FNS_Dataset_2023
# Out:
# /content/drive/MyDrive/FNS_Dataset_2023

# %%
import os

def count_files_in_folder(folder_path):
    return len([name for name in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, name))])

# Usage
annual_reports = '/content/drive/MyDrive/FNS_Dataset_2023/training/annual_reports'
gold_summaries = '/content/drive/MyDrive/FNS_Dataset_2023/training/gold_summaries'  # replace with your folder path
print("Number of annual reports: ",count_files_in_folder(annual_reports))
print("Number of gold summaries: ",count_files_in_folder(gold_summaries))
# Out:
# Number of annual reports:  3050
# Number of gold summaries:  10007

# %%
# !pip install stanza
# Out:
# Collecting stanza
#   Downloading stanza-1.6.1-py3-none-any.whl (881 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.2/881.2 kB 16.9 MB/s eta 0:00:00
# Collecting emoji (from stanza)
#   Downloading emoji-2.8.0-py2.py3-none-any.whl (358 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.9/358.9 kB 35.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stanza) (1.23.5)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (3.20.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from stanza) (2.31.0)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (2.0.1+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stanza) (4.66.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.3.0->stanza) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.3.0->stanza) (17.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3.0->stanza) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3.0->stanza) (1.3.0)
# Installing collected packages: emoji, stanza
# Successfully installed emoji-2.8.0 stanza-1.6.1

# %%
import numpy as np
import pandas as pd

import stanza
import spacy
import nltk
import re
import json
import os
from tqdm import tqdm
from bs4 import BeautifulSoup

from tqdm.notebook import tqdm
tqdm.pandas()

# %%
# !pip install stop_words
# Out:
# Collecting stop_words
#   Downloading stop-words-2018.7.23.tar.gz (31 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: stop_words
#   Building wheel for stop_words (setup.py) ... done
#   Created wheel for stop_words: filename=stop_words-2018.7.23-py3-none-any.whl size=32896 sha256=65f58e1e570049efd08a11575386f9ed4c9215a15a991e3f54c9f9f2332554d6
#   Stored in directory: /root/.cache/pip/wheels/d0/1a/23/f12552a50cb09bcc1694a5ebb6c2cd5f2a0311de2b8c3d9a89
# Successfully built stop_words
# Installing collected packages: stop_words
# Successfully installed stop_words-2018.7.23

# %%
from nltk.tokenize import RegexpTokenizer
from nltk.stem import SnowballStemmer
from nltk.tokenize import word_tokenize
from stop_words import get_stop_words
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
stanza.download('en')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Downloading default packages for language: en (English) ...
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.6.0/models/default.zip:   0%|          | 0…
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources.

# %%
spacy_pipline = dict()
spacy_pipline['en'] = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# %%
stemmer = dict()
stemmer['en'] = SnowballStemmer("english")

# %%
def preprocess_text(text, lang='en'):
    #remove html tags
    # text = BeautifulSoup(text, "html.parser").get_text()

    #remove links
    text = re.sub(r"https?:\/\/\S+\b|www\.(\w+\.)+\S*", "", text)

    #remove text between []
    text = re.sub('\[[^]]*\]', '', text)

    #fix contractions
    def decontracted(phrase):

        phrase = re.sub("\u2019", '\'', phrase)
        phrase = re.sub("\u2018", '\'', phrase)
        phrase = re.sub("\u201C", '\"', phrase)
        phrase = re.sub("\u201D", '\"', phrase)

        # specific
        phrase = re.sub(r"won\'t", "will not", phrase)
        phrase = re.sub(r"can\'t", "can not", phrase)

        # general
        phrase = re.sub(r"n\'t", " not", phrase)
        phrase = re.sub(r"\'re", " are", phrase)
        phrase = re.sub(r"\'s", " is", phrase)
        phrase = re.sub(r"\'d", " would", phrase)
        phrase = re.sub(r"\'ll", " will", phrase)
        phrase = re.sub(r"\'t", " not", phrase)
        phrase = re.sub(r"\'ve", " have", phrase)
        phrase = re.sub(r"\'m", " am", phrase)

        return phrase

    text = decontracted(text)

    #Remove numbers
    text = re.sub(r"[-+]?[.\d]*[\d]+[:,.\d]*", "", text)

    #lowercase
    text = text.lower()

    # tokenize the string
    # remove punctuation and special characters
    text = re.sub(r'[_]', ' ', text)
    text = re.sub(r'[\r|\n|\r\n]+', ' ', text)
    tokenizer = RegexpTokenizer(r'\w+')

    text = tokenizer.tokenize(text)

    #Remove stopwords
    stopwords = set(get_stop_words(lang))
    text = [i for i in text if i not in stopwords]

    # #Stemming
    # text = [stemmer[lang].stem(word) for word in text]

    #Lemmatize
    text = [word for word in text if word is not None]
    doc = spacy_pipline[lang](' '.join(text))

    if lang == 'ar' or lang == 'tr':
        if (len(doc.sentences) != 0):
            text = [token.lemma for token in doc.sentences[0].words]
    else:
        text = [token.lemma_ for token in doc]

    return text

# %% [markdown]
# # Extract Report and Summary

# %%
report_dir = '/content/drive/MyDrive/FNS_Dataset_2023/training/annual_reports'
summaries_dir = "/content/drive/MyDrive/FNS_Dataset_2023/training/gold_summaries"

# %%
files = os.listdir(report_dir)
data = {'id':[], 'report':[]}

for f in tqdm(files):
    text_file = open(os.path.join(report_dir, f), 'r', encoding = 'utf-8')
    content = text_file.read()

    # pre-process the data
    # data = dict()
    # data['text'] = preprocess_text(content)

    # with open(os.path.join(dest, str(f[0:-3]) + "json"), 'w', encoding='utf-8') as outfile:
    #     json.dump(data, outfile)

    data['id'].append(f[0:-4])
    data['report'].append(content)
# Out:
#   0%|          | 0/3050 [00:00<?, ?it/s]

# %%
df_combined = pd.DataFrame.from_dict(data)
df_combined.set_index('id', inplace=True)
df_combined.head()
# Out:
#                                                   report
# id
# 18772   24303.04    10 November 2015 12:43 PM   proof...
# 15256   Synergy Health plc  \nAnnual Report and Accou...
# 14148   Shanks Group plc Annual Report and Accounts 2...
# 17441   Annual Report & Accounts\n2012 Contents\nWynn...
# 24935   HSBC Holdings plc \nAnnual Report and Account...

# %%
summ = os.listdir(summaries_dir)

# %%
for f in tqdm(summ):
  id = f[0:-4].split('_')[0]
  num = f[0:-4].split('_')[1]

  text_file = open(os.path.join(summaries_dir, f), 'r', encoding = 'utf-8')
  content = text_file.read()

  df_combined.loc[id, 'summary_' + str(num)] = content
# Out:
#   0%|          | 0/10007 [00:00<?, ?it/s]

# %%
df_combined.head()
# Out:
#                                                   report  \
# id
# 18772   24303.04    10 November 2015 12:43 PM   proof...
# 15256   Synergy Health plc  \nAnnual Report and Accou...
# 14148   Shanks Group plc Annual Report and Accounts 2...
# 17441   Annual Report & Accounts\n2012 Contents\nWynn...
# 24935   HSBC Holdings plc \nAnnual Report and Account...
#
#                                                summary_2  \
# id
# 18772   24303.04    10 November 2015 12:43 PM   proof...
# 15256   2010 2011 2012 2013 2014\n286.4 287.3\n312.0\...
# 14148   2 shanks. annual report 2008\nfinancial highl...
# 17441   1 Wynnstay Group Plc Annual Report & Accounts...
# 24935   HSBC HOLDINGS PLC \nReport of the Directors: ...
#
#                                                summary_3  \
# id
# 18772   24303.04    10 November 2015 12:43 PM   proof...
# 15256   Synergy remains well placed  \nto exploit its...
# 14148   shanks. annual report 2008 3\nchairman’s stat...
# 17441   6 www.wynnstay.co.uk\nOVERVIEW\nIn my first s...
# 24935   HSBC HOLDINGS PLC \nReport of the Directors: ...
#
#                                                summary_4  \
# id
# 18772                                                NaN
# 15256   1\n2\n3\n4\n1. UK & Ireland £164.7m\n2. Europ...
# 14148                                                NaN
# 17441   4 www.wynnstay.co.uk\nOur business at a glanc...
# 24935                                                NaN
#
#                                                summary_1  \
# id
# 18772   24303.04    10 November 2015 12:43 PM   proof...
# 15256   Strategic report \nChief Executive's strategi...
# 14148   4 shanks. annual report 2008\nI joined as Gro...
# 17441   10 www.wynnstay.co.uk\nINTRODUCTION \nThe Gro...
# 24935   7\nOverview Operating & Financial Review Gove...
#
#                                                summary_5 summary_6 summary_7
# id
# 18772   24303.04    10 November 2015 12:43 PM   proof...       NaN       NaN
# 15256                                                NaN       NaN       NaN
# 14148                                                NaN       NaN       NaN
# 17441                                                NaN       NaN       NaN
# 24935                                                NaN       NaN       NaN

# %%
# df_combined.drop(['summary_2', 'summary_3', 'summary_4', 'summary_5', 'summary_6', 'summary_7'], axis=1)

# %%
def common_unigram(text1, text2):
  if text1 is np.nan or text2 is np.nan:
      return 0

  return len(set(text1) & set(text2))

# %%
s1 = preprocess_text(df_combined.iloc[0]['summary_1'])
s2 = preprocess_text(df_combined.iloc[0]['summary_2'])

print('summary_1', s1)
print('\n\nsummary_2', s2)
print(common_unigram(s1, s2))
# Out:
# summary_1 ['november', 'pm', 'proof', 'q', 'st', 'rateg', 'y', 'w', 'h', 'ceo', 'step', 'hen', 'w', 'ick', 'target', 'increase', 'land', 'bank', 'net', 'end', 'june', 'find', 'business', 'model', 'page', 'read', 'online', 'q', 'cou', 'ld', 'exp', 'lain', 't', 'logic', 'hind', 't', 'significant', 'g', 'rowt', 'h', 'hou', 'sebu', 'ilding', 'act', 'ivity', 'inte', 'nd', 'cont', 'inue', 't', 'futu', 're', 'inland', 'home', 'extract', 'maximum', 'value', 'well', 'locate', 'land', 'bank', 'strategy', 'acquire', 'brownfield', 'site', 'pre', 'planning', 'stage', 'long', 'track', 'record', 'planning', 'success', 'position', 'group', 'housebuilder', 'exceptional', 'skill', 'large', 'scale', 'brownfield', 'development', 'capitalise', 'favourable', 'market', 'condition', 'order', 'significantly', 'increase', 'housebuilding', 'activity', 'intend', 'maintain', 'growth', 'strategy', 'enhance', 'land', 'bank', 'however', 'change', 'condition', 'company', 'may', 'realign', 'strategy', 'accordingly', 'q', 'inland', 'home', 's', 'land', 'b', 'ank', 'increase', 'conside', 'rably', 'ove', 'r', 'plot', 's', 'r', 't', 'arget', 'growt', 'h', 'ove', 'r', 't', 'next', 'mo', 'not', 'hs', 'target', 'increase', 'land', 'bank', 'net', 'end', 'june', 'group', 'exhibit', 'solid', 'performance', 'throughout', 'financial', 'year', 'exceed', 'consensus', 'estimate', 'strong', 'land', 'bank', 'confident', 'housebuilder', 'will', 'see', 'development', 'opportunity', 'deem', 'financially', 'beneficial', 'company', 'will', 'sell', 'site', 'housebuilder', 'q', 'r', 'current', 'p', 'roject', 's', 'expe', 'ct', 't', 'p', 'rimary', 'cash', 'ge', 'nerat', 'ors', 't', 'financial', 'ye', 'ar', 'end', 'ju', 'ne', 'inland', 'home', 'currently', 'work', 'number', 'project', 'will', 'cash', 'generative', 'current', 'year', 'one', 'notable', 'development', 'expect', 'meridian', 'tv', 'studio', 'southampton', 'additionally', 'joint', 'venture', 'cpc', 'group', 'limit', 'develop', 'brookland', 'college', 'site', 'ashford', 'middlesex', 'will', 'accommodate', 'approximately', 'new', 'home', 'subject', 'planning', 'permission', 'gross', 'development', 'value', 'order', 'm', 'q', 't', 'p', 're', 'e', 'lect', 'ion', 'uncert', 'ainty', 't', 'uk', 'impact', 't', 'comp', 's', 'growt', 'h', 'st', 'rateg', 'y', 'market', 'cool', 'slightly', 'ahead', 'general', 'election', 'decrease', 'activity', 'across', 'sector', 'uncertainty', 'general', 'election', 'impact', 'housing', 'market', 'mortgage', 'housing', 'approval', 'slow', 'despite', 'exceed', 'land', 'bank', 'growth', 'estimate', 'year', 'market', 'pick', 'new', 'government', 'q', 'last', 'ye', 'ar', 're', 've', 'ry', 'po', 'sit', 'I', 've', 'drayto', 'n', 'garde', 'n', 'village', 'can', 'upd', 'ate', 'we', 't', 'progress', 'drayton', 'garden', 'village', 'successful', 'year', 'yet', 'now', 'approach', 'end', 'june', 'apartment', 'building', 'plot', 'sell', 'national', 'housebuilder', 'm', 'last', 'significant', 'parcel', 'land', 'site', 'phase', 'housing', 'unit', 'build', 'inland', 'complete', 'year', 'end', 'price', 'excess', 'budget', 'intend', 'obtain', 'plan', 'eight', 'apartment', 'plot', 'next', 'month', 'stephen', 'w', 'ick', 'chief', 'executive', 'officer', 'inland', 'homes', 'plc', 'annual', 'report', 'account', 'year', 'end', 'june', 'november', 'pm', 'proof', 'q', 'inland', 'home', 's', 'move', 't', 'p', 'rivate', 'rent', 'al', 'sect', 'follow', 'ing', 't', 'acquisit', 'ion', 'hou', 'ses', 't', 'comp', 's', 'wilt', 'park', 'beaconsfield', 'deve', 'lop', 'ment', 'impact', 'w', 'ill', 't', 't', 'bu', 'siness', 'move', 'forward', 'inte', 'nd', 'increase', 't', 'numbe', 'r', 'rent', 'al', 'prope', 'rt', 'ies', 'ow', 'ned', 't', 'current', 'financial', 'ye', 'ar', 'intend', 'hold', 'exist', 'house', 'investment', 'property', 'significant', 'value', 'uplift', 'envisage', 'cost', 'property', 'already', 'agree', 'lease', 'house', 'confirm', 'strong', 'demand', 'rental', 'stock', 'fully', 'let', 'house', 'expect', 'generate', 'gro ...
#
#
# summary_2 ['november', 'pm', 'proof', 'financial', 'ope', 'rat', 'ional', 'highlight', 's', 'financial', 'highlight', 's', 'revenue', 'increase', 'm', 'restate', 'm', 'profit', 'tax', 'include', 'm', 'revaluation', 'surplus', 'increase', 'm', 'restate', 'm', 'earning', 'per', 'share', 'increase', 'p', 'restate', 'p', 'total', 'dividend', 'interim', 'p', 'plus', 'propose', 'final', 'p', 'per', 'share', 'increase', 'p', 'p', 'net', 'asset', 'per', 'share', 'increase', 'p', 'restate', 'p', 'exclude', 'unrealised', 'gain', 'within', 'inventory', 'year', 'end', 'cash', 'balance', 'm', 'restate', 'm', 'net', 'gearing', 'restate', 'total', 'borrowing', 'less', 'cash', 'proportion', 'shareholder', 'fund', 'ope', 'rat', 'ional', 'highlight', 's', 'record', 'performance', 'well', 'ahead', 'market', 'expectation', 'expansion', 'housebuilde', 'programme', 'add', 'significantly', 'result', 'private', 'home', 'sell', 'year', 'creation', 'residential', 'investment', 'property', 'portfolio', 'contribute', 'm', 'revaluation', 'surplus', 'annual', 'rental', 'income', 'exceed', 'm', 'post', 'year', 'end', 'land', 'bank', 'continue', 'grow', 'currently', 'stand', 'plot', 'plot', 'consent', 'reve', 'nue', 'm', 'restate', 'm', 'm', 'm', 'm', 'm', 'm', 'net', 'asset', 'v', 'alue', 'pe', 'r', 'share', 'p', 'restate', 'p', 'p', 'p', 'p', 'p', 'p', 'profit', 'fore', 't', 'ax', 'm', 'restate', 'm', 'm', 'm', 'm', 'm', 'm', 'divide', 'nd', 'pe', 'r', 'share', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'basic', 'earning', 'pe', 'r', 'share', 'p', 'restate', 'p', 'p', 'p', 'p', 'p', 'p', 'ye', 'ar', 'end', 'cash', 'balance', 'm', 'restate', 'm', 'm', 'm', 'm', 'm', 'm', 'plot', 'land', 'b', 'ank', 'due', 'introduction', 'ifrs', 'group', 'consolidate', 'result', 'drayton', 'garden', 'village', 'ltd', 'dgvl', 'year', 'end', 'june', 'prior', 'year', 'account', 'ias', 'sic', 'standard', 'require', 'consolidation', 'dgvl', 'read', 'online', 'read', 'finance', 'director', 'review', 'page', 'read', 'chief', 'executive', 'review', 'page', 'inland', 'homes', 'plc', 'annual', 'report', 'account', 'year', 'end', 'june', 'november', 'pm', 'proof', 'site', 'entrance', 'drayton', 'garden', 'village', 'west', 'drayton', 'middlesex', 'complete', 'development', 'queensgate', 'farnborough', 'hampshire', 'marketing', 'suite', 'carter', 'quay', 'poole', 'dorset', 'artist', 'impression', 'swallow', 'street', 'iver', 'buckinghamshire', 'marketing', 'suite', 'west', 'plaza', 'ashford', 'middlesex', 'showhome', 'queensgate', 'farnborough', 'hampshire', 'consent', 'p', 'lot', 's', 'land', 'b', 'ank', 'private', 'hou', 'sing', 'complet', 'ion', 't', 'ye', 'ar', 'plot', 's', 't', 'land', 'b', 'ank', 'november', 'pm', 'proof', 'st', 'rateg', 'ic', 'repo', 'rt', 'artist', 'impression', 'vale', 'acton', 'west', 'london', 'november', 'pm', 'proof', 'm', 'current', 'annual', 'rent', 'al', 'income', 'w', 'ith', 'purchasers', 'confidence', 'high', 'support', 'removal', 'political', 'uncertainty', 'continue', 'strong', 'demand', 'home', 'build', 'land', 'every', 'confidence', 'deliver', 'significant', 'progress', 'current', 'financial', 'year', 'stephen', 'w', 'ick', 'chief', 'executive', 'officer', 'inside', 't', 'sect', 'ion', 'chairman', 'statement', 'marketplace', 'agile', 'business', 'model', 'strategy', 'q', 'strategy', 'ceo', 'stephen', 'w', 'ick', 'q', 'finance', 'finance', 'director', 'nishith', 'malde', 'q', 'land', 'strategy', 'land', 'director', 'paul', 'brett', 'q', 'planning', 'planning', 'director', 'mark', 'gilpin', 'case', 'study', 'w', 'ilton', 'park', 'beaconsfield', 'kpi', 'chief', 'executive', 'review', 'case', 'study', 'meridian', 'waterside', 'southampton', 'finance', 'director', 'review', 'risk', 'risk', 'management', 'corporate', 'social', 'ethical', 'environmental', 'responsibility', 'case', 'study', 'brookland', 'college', 'ashford', 'showhome', 'drayton', 'garden', 'village', 'west', 'drayton', 'middlesex']
# 94

# %%
best_summary = dict()

for index, row in tqdm(df_combined.iterrows(), total=len(df_combined)):
    overlap_matrix = []

    # Find the first available summary column
    best_index = 1
    for i in range(1, 8):
        if not pd.isnull(row["summary_" + str(i)]):
            best_index = i
            break

    best_overlap = -np.inf

    for i in range(best_index, 8):
        if pd.isnull(row["summary_" + str(i)]):
            break

        summary_a = preprocess_text(row["summary_" + str(i)])

        if len(summary_a) == 0:
            break

        temp = []
        for j in range(best_index, 8):
            if pd.isnull(row["summary_" + str(j)]):
                break

            summary_b = preprocess_text(row["summary_" + str(j)])

            if len(summary_b) == 0:
                break

            overlap = common_unigram(summary_a, summary_b)
            temp.append(overlap)

        score = sum(temp) / len(summary_a)

        if best_overlap < score:
            best_overlap = score
            best_index = i

    best_summary[index] = (best_index, best_overlap)
# Out:
#   0%|          | 0/3050 [00:00<?, ?it/s]

# %%
best_summary
# Out:
# {'18772': (2, 0.9351851851851852),
#  '15256': (2, 1.2652259332023577),
#  '14148': (3, 0.707808564231738),
#  '17441': (2, 1.131578947368421),
#  '24935': (2, 0.7211895910780669),
#  '18014': (2, 0.8929889298892989),
#  '15530': (2, 1.1369863013698631),
#  '15524': (2, 0.7719298245614035),
#  '3205': (2, 0.7980392156862746),
#  '5112': (2, 1.2211538461538463),
#  '12277': (2, 1.0672097759674135),
#  '17455': (1, 1.062135922330097),
#  '5648': (2, 1.4855491329479769),
#  '4230': (2, 1.0168067226890756),
#  '17469': (2, 1.0723404255319149),
#  '7739': (2, 1.4698795180722892),
#  '804': (2, 1.5367965367965368),
#  '12511': (2, 1.3641304347826086),
#  '8595': (2, 1.0817610062893082),
#  '16824': (2, 1.5226130653266332),
#  '16830': (2, 2.5555555555555554),
#  '8581': (2, 0.9148264984227129),
#  '2912': (2, 1.4615384615384615),
#  '757': (2, 1.5174129353233832),
#  '13974': (2, 3.090909090909091),
#  '6584': (2, 1.151624548736462),
#  '5933': (2, 1.56),
#  '2084': (2, 0.865979381443299),
#  '16818': (2, 1.16),
#  '14028': (2, 1.5087719298245614),
#  '8224': (2, 1.3472222222222223),
#  '3403': (2, 1.28),
#  '964': (2, 0.8933333333333333),
#  '8542': (2, 1.0108303249097472),
#  '10500': (2, 1.028),
#  '19242': (3, 1.167832167832168),
#  '14772': (1, 1.3703703703703705),
#  '9112': (2, 2.3333333333333335),
#  '10514': (2, 1.109375),
#  '4344': (3, 0.6719033232628399),
#  '4422': (2, 1.4017857142857142),
#  '227': (2, 1.5177304964539007),
#  '7895': (2, 1.4958677685950412),
#  '6553': (2, 1.6934306569343065),
#  '20158': (2, 1.05019305019305),
#  '10925': (2, 1.5294117647058822),
#  '233': (2, 4.0),
#  '15691': (2, 1.4363636363636363),
#  '12854': (2, 0.9704142011834319),
#  '8973': (2, 1.8562874251497006),
#  '24302': (2, 1.1085526315789473),
#  '2286': (3, 1.0),
#  '18362': (2, 1.8333333333333333),
#  '8967': (2, 1.13151364764268),
#  '19097': (2, 1.106951871657754),
#  '1016': (4, 1.702127659574468),
#  '15120': (2, 1.6810344827586208),
#  '13223': (2, 1.4545454545454546),
#  '11434': (2, 0.968),
#  '2437': (2, 1.1097560975609757),
#  '131': (2, 1.3674698795180722),
#  '5358': (2, 1.5172413793103448),
#  '1472': (2, 1.2783505154639174),
#  '14882': (2, 1.13903743315508),
#  '18060': (2, 2.0847457627118646),
#  '680': (2, 0.19813519813519814),
#  '11736': (2, 1.1313868613138687),
#  '4536': (2, 0.9726618705035971),
#  '8324': (3, 1.163776493256262),
#  '12571': (2, 1.3859649122807018),
#  '2635': (3, 1.1170483460559797),
#  '16717': (2, 1.9333333333333333),
#  '6447': (2, 1.5605095541401275),
#  '2153': (2, 1.2642276422764227),
#  '11695': (2, 1.164179104477612),
#  '6453': (2, 2.1844660194174756),
#  '723': (2, 1.0909090909090908),
#  '21030': (2, 1.8148148148148149),
#  '7822': (2, 1.1788617886178863),
#  '2782': (2, 2.2054794520547945),
#  '18841': (2, 1.203125),
#  '23182': (2, 0.16455696202531644),
#  '10548': (2, 0.841726618705036),
#  '19587': (3, 0.9728813559322034),
#  '3477': (2, 1.5157894736842106),
#  '16139': (3, 0.775609756097561),
#  '17227': (2, 1.1842105263157894),
#  '5006': (2, 1.3504273504273505),
#  '8536': (2, 0.990990990990991),
#  '938': (2, 1.4191616766467066),
#  '16893': (2, 0.948509485094851),
#  '19578': (2, 1.0),
#  '7605': (2, 0.8881431767337807),
#  '9600': (2, 1.0149253731343284),
#  '11118': (1, 1.0108225108225108),
#  '16663': (2, 0.8680445151033387),
#  '18882': (2, 1.6899563318777293),
#  '2999': (2, 2.225),
#  '2741': (2, 1.4497354497354498),
#  '14706': (2, 1.106060606060606),
#  '19544': (2, 1.0139664804469273),
#  '8091': (2, 0.9745762711864406),
#  '10560': (3, 1.2237442922374429),
#  '10789': (2, 1.5),
#  '25040': (2, 1.0853658536585367),
#  '24438': (2, 1.233160621761658),
#  '6902': (2, 4.0),
#  '4683': (3, 1.069767441860465),
#  '17794': (3, 0.9833333333333333),
#  '19949': (2, 1.2454545454545454),
#  '6094': (2, 1.6774193548387097),
#  '22061': (2, 1.588235294117647),
#  '3846': (2, 1.8015873015873016),
#  '2580': (2, 1.3135593220338984),
#  '22075': (2, 1.0095238095238095),
#  '11454': (2, 1.854014598540146),
#  '22920': (3, 0.9370629370629371),
#  '22713': (2, 1.2193548387096773),
#  '18302': (2, 1.153179190751445),
#  '2219': (2, 1.372093023255814),
#  '16449': (2, 2.121212121212121),
#  '25083': (2, 1.639344262295082),
#  '22934': (2, 1.3636363636363635),
#  '15140': (2, 0.9832402234636871),
#  '9402': (2, 1.7647058823529411),
#  '5238': (2, 1.627659574468085),
#  '6057': (2, 0.9235294117647059),
#  ...}

# %%
from tqdm.notebook import tqdm
tqdm.pandas()

df_combined['best_summary_index'], df_combined['best_summary_score'] = zip(*df_combined.index.map(lambda x: best_summary.get(x, (None, None))))

# %%
df_combined.head()
# Out:
#                                                   report  \
# id
# 18772   24303.04    10 November 2015 12:43 PM   proof...
# 15256   Synergy Health plc  \nAnnual Report and Accou...
# 14148   Shanks Group plc Annual Report and Accounts 2...
# 17441   Annual Report & Accounts\n2012 Contents\nWynn...
# 24935   HSBC Holdings plc \nAnnual Report and Account...
#
#                                                summary_2  \
# id
# 18772   24303.04    10 November 2015 12:43 PM   proof...
# 15256   2010 2011 2012 2013 2014\n286.4 287.3\n312.0\...
# 14148   2 shanks. annual report 2008\nfinancial highl...
# 17441   1 Wynnstay Group Plc Annual Report & Accounts...
# 24935   HSBC HOLDINGS PLC \nReport of the Directors: ...
#
#                                                summary_3  \
# id
# 18772   24303.04    10 November 2015 12:43 PM   proof...
# 15256   Synergy remains well placed  \nto exploit its...
# 14148   shanks. annual report 2008 3\nchairman’s stat...
# 17441   6 www.wynnstay.co.uk\nOVERVIEW\nIn my first s...
# 24935   HSBC HOLDINGS PLC \nReport of the Directors: ...
#
#                                                summary_4  \
# id
# 18772                                                NaN
# 15256   1\n2\n3\n4\n1. UK & Ireland £164.7m\n2. Europ...
# 14148                                                NaN
# 17441   4 www.wynnstay.co.uk\nOur business at a glanc...
# 24935                                                NaN
#
#                                                summary_1  \
# id
# 18772   24303.04    10 November 2015 12:43 PM   proof...
# 15256   Strategic report \nChief Executive's strategi...
# 14148   4 shanks. annual report 2008\nI joined as Gro...
# 17441   10 www.wynnstay.co.uk\nINTRODUCTION \nThe Gro...
# 24935   7\nOverview Operating & Financial Review Gove...
#
#                                                summary_5 summary_6 summary_7  \
# id
# 18772   24303.04    10 November 2015 12:43 PM   proof...       NaN       NaN
# 15256                                                NaN       NaN       NaN
# 14148                                                NaN       NaN       NaN
# 17441                                                NaN       NaN       NaN
# 24935                                                NaN       NaN       NaN
#
#        best_summary_index  best_summary_score
# id
# 18772                   2            0.935185
# 15256                   2            1.265226
# 14148                   3            0.707809
# 17441                   2            1.131579
# 24935                   2            0.721190

# %%
report= df_combined.loc['846', 'summary_1']
print(len(report))
best_summary['846']
# Out:
# 5
# (1, -inf)

# %%
# List to store indices with best_summary_score == -inf
indices_with_negative_inf = []

for index, (best_index, best_overlap) in best_summary.items():
    if best_overlap == float('-inf'):
        indices_with_negative_inf.append(index)

# Print the indices with best_summary_score == -inf
print("Indices with best_summary_score == -inf:", indices_with_negative_inf)
# Out:
# Indices with best_summary_score == -inf: ['14018', '846', '7497']

# %%
# List of indices with best_summary_score == -inf
indices_to_drop = [index for index, (_, best_overlap) in best_summary.items() if best_overlap == float('-inf')]

# Drop rows with the specified indices
df_combined.drop(indices_to_drop, inplace=True)

# Reset the index after dropping rows
df_combined.reset_index(drop=True, inplace=True)

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3047 entries, 0 to 3046
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   report              3047 non-null   object
#  1   summary_2           3043 non-null   object
#  2   summary_3           3042 non-null   object
#  3   summary_4           735 non-null    object
#  4   summary_1           3040 non-null   object
#  5   summary_5           127 non-null    object
#  6   summary_6           8 non-null      object
#  7   summary_7           1 non-null      object
#  8   best_summary_index  3047 non-null   int64
#  9   best_summary_score  3047 non-null   float64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 238.2+ KB

# %%
df_combined.to_csv('/content/traindata.csv', index=True, escapechar='\\')

# %%
traindf=pd.read_csv('/content/traindata.csv')

# %%
traindf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3047 entries, 0 to 3046
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          3047 non-null   int64
#  1   report              3047 non-null   object
#  2   summary_2           3043 non-null   object
#  3   summary_3           3042 non-null   object
#  4   summary_4           735 non-null    object
#  5   summary_1           3040 non-null   object
#  6   summary_5           127 non-null    object
#  7   summary_6           8 non-null      object
#  8   summary_7           1 non-null      object
#  9   best_summary_index  3047 non-null   int64
#  10  best_summary_score  3047 non-null   float64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 262.0+ KB
