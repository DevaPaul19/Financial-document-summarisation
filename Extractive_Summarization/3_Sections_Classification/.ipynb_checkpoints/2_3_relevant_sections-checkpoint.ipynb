# %%
import pandas as pd
import pickle

from get_relevant_sections import get_relevant_sections_with_scores

# %%
TRAINING_DATASET = False
VALIDATION_DATASET = False
TEST_DATASET = True

# %%
if TRAINING_DATASET:
    df_predicted = pickle.load(open('out/training_df_predicted.pkl', 'rb'))
    
if VALIDATION_DATASET:
    df_predicted = pickle.load(open('out/validation_df_predicted.pkl', 'rb'))
    
if TEST_DATASET:
    df_predicted = pickle.load(open('out/test_df_predicted.pkl', 'rb'))

df_predicted.head()
# Out:
#    file_id               toc_section  toc_section_pos  toc_section_len  \
# 0    25082           Highlights 2011               45               37
# 1    25082               Impax Facts               82               57
# 2    25082      Chairman’s Statement              139              273
# 3    25082               Our history              412               41
# 4    25082  Chief Executive’s Report              453              371
#
#    toc_section_cleaned  pred     False      True
# 0            highlight     1  0.006433  0.993567
# 1           impax fact     0  0.758737  0.241263
# 2   chairman statement     1  0.018208  0.981792
# 3              histori     0  0.776262  0.223738
# 4  chief execut report     1  0.045702  0.954298

# %%
get_relevant_sections_with_scores(df_predicted)
# Out:
# file_id:  25082 .txt
# ['Highlights 2011', 'Chairman’s Statement', 'Chief Executive’s Report']
# [0.9935666499910996, 0.9817918056034987, 0.9542977285314015]
#
#
# file_id:  25110 .txt
# ['Highlights', 'Impellam at a glance', 'Chairman’s statement', 'Group Chief Executive Officer’s review']
# [0.9934754173755347, 0.9128674137038355, 0.9812661573338014, 0.9556070941214052]
#
#
# file_id:  25111 .txt
# ['Performance Highlights', 'Chairman’s Statement', 'Chief Executive’s Statement', 'Chairman’s Introduction']
# [0.9192730116040663, 0.9815968074212891, 0.980197677959904, 0.662963530336711]
#
#
# file_id:  25118 .txt
# ['Chairman’s statement', 'Business highlights', 'Financial highlights', 'Chief Executive’s report']
# [0.9813508323287512, 0.91128404327901, 0.8800161792566449, 0.954862794136725]
#
#
# file_id:  25120 .txt
# ['Highlights', 'Chairman’s statement', 'Chief Executive Officer’s interview', 'Chief Executive Officer’s review']
# [0.9934813922119483, 0.9815154035203094, 0.9807432032411453, 0.9690292073236076]
#
#
# file_id:  25130 .txt
# ['start', 'Chief Executive’s review', 'Chairman’s statement']
# [0.8776202630275779, 0.9927650504643127, 0.9717362809982278]
#
#
# file_id:  25177 .txt
# ['Highlights', 'Chairman’s Statement', 'Chief Executive’s Review']
# [0.9935567737986916, 0.9816551094158958, 0.9929528326270917]
#
#
# file_id:  25184 .txt
# ['Highlights', 'Informa at a glance', 'Chairman’s introduction', 'Group Chief Executive’s review']
# [0.9935519707205099, 0.7063792227582014, 0.7445074957351681, 0.9827165327476125]
#
#
# file_id:  25242 .txt
# ['Financial Highlights', 'Operational Highlights', 'Chairman’s Statement', 'Chief Executive’s Review']
# [0.8814983791915358, 0.8879709943826594, 0.9809964260622018, 0.9911203061904511]
#
#
# file_id:  25246 .txt
# ['Financial highlights', 'Business highlights', 'Group at a glance', 'Chairman’s statement', 'Chief Executive’s strategic review']
# [0.8825145575581459, 0.9129679288467838, 0.8146491341474993, 0.9813437390678922, 0.9630289178421548]
#
#
# file_id:  25260 .txt
# ['Highlights', 'Group at a glance', 'Chairman’s statement', 'Chief Executive Officer’s statement']
# [0.9935867215924029, 0.815805699736602, 0.9815429833481238, 0.9647193903832311]
#
#
# file_id:  25261 .txt
# ['Highlights', 'Group at a glance', 'Chairman’s statement', 'Chief Executive Officer’s statement']
# [0.9935959801966089, 0.814048781626368, 0.9813671671770117, 0.9652256197964231]
#
#
# file_id:  25268 .txt
# ['Highlights', 'Chairman’s Statement', 'Chief Executive Officer’s Statement']
# [0.993538645510654, 0.9814438676061523, 0.9662986555933091]
#
#
# file_id:  25269 .txt
# ['start', 'Chairman’s Statement', 'Chief Executive Officer’s Review']
# [0.8776149102655989, 0.9815883819206138, 0.9738711746574439]
#
#
# file_id:  25276 .txt
# ['IDH at a Glance', '2016 Highlights', 'A Note from Our Chairman']
# [0.7921046965523056, 0.993587940823333, 0.7285901904172176]
#
#
# file_id:  25277 .txt
# ['Business at a glance', 'Chairman’s statement', 'Group Chief Executive Officer’s review']
# [0.7299482027957351, 0.9808105522742666, 0.95575420511577]
#
#
# file_id:  25281 .txt
# ['IHG at a glance', 'Chairman’s statement', 'Chief Executive Officer’s review', 'Regional highlights', 'Chairman’s overview']
# [0.9146423922448187, 0.9813343507788862, 0.9731380464908876, 0.9455692119802506, 0.6913059029927311]
#
#
# file_id:  25295 .txt
# ['start', 'Chairman’s statement', 'An introduction from the Chief Executive', 'Chief Executive Officer’s review', 'Letter from the Chairman', 'Compensation at a glance']
# [0.8766500383447186, 0.981634399883547, 0.9886228876202041, 0.9694667839217446, 0.746622473818534, 0.8186383971248212]
#
#
# file_id:  25317 .txt
# ['Group at a glance', 'Group highlights', 'Chairman’s statement', 'Chief Executive Officer’s review']
# [0.8158996312560424, 0.9236000866717504, 0.98106642260658, 0.9733283582008666]
#
#
# file_id:  25318 .txt
# ['Group highlights', 'Group at a glance', 'Chairman’s statement', 'Chief Executive Officer’s review']
# [0.9236757002789812, 0.8113642666696202, 0.980682817580799, 0.9730346697816353]
#
#
# file_id:  25319 .txt
# ['Highlights', 'Group at a glance', 'Chairman’s statement', 'Chief Executive Officer’s review']
# [0.9935018270256541, 0.813946517118778, 0.9805453166533943, 0.9725090236587123]
#
#
# file_id:  25321 .txt
# ['Performance highlights', 'Chairman’s statement', 'Chief Executive Ofﬁ cer’s statement']
# [0.9188621009861936, 0.9810635735989148, 0.9422169642016326]
#
#
# file_id:  25322 .txt
# ['Performance highlights', 'Chairman’s statement', 'Chief Executive Officer’s statement']
# [0.9185512658532554, 0.9807165008482601, 0.9641993917677861]
#
#
# file_id:  25323 .txt
# ['Performance highlights', 'Chairman’s statement', 'Chief Executive Offi cer’s review']
# [0.919217776194376, 0.9816351474735563, 0.9280493901314479]
#
#
# file_id:  25324 .txt
# ['Performance highlights', 'Chairman’s statement', 'IPF at a glance', 'Chief Executive Officer’s review']
# [0.9187113730061827, 0.9816080609958114, 0.9115737191021189, 0.9719849813473572]
#
#
# file_id:  25336 .txt
# ['Financial highlights', 'Chief Executive Officer’s review', 'Intertek Executive Management Team', 'Chairman’s statement', 'Chairman’s introduction']
# [0.8825571173233341, 0.9725382134030324, 0.5089898255412941, 0.9685579418447627, 0.6227072987512058]
#
#
# file_id:  25456 .txt
# ['Financial highlights', 'Chairman’s statement', 'Chief Executive Officer’s and Chief Operating Officer’s review']
# [0.884032860654272, 0.9816246327352267, 0.9329713324291219]
#
#
# file_id:  25532 .txt
# ['Business and financial highlights', "Chairman's statement", 'Chief executive officer’s statement']
# [0.7643466999171711, 0.9818077916117988, 0.9663012216163057]
#
#
# file_id:  25533 .txt
# ['Highlights', 'At a Glance', 'Chairman’s Statement', 'Chief Executive Officer’s Statement']
# [0.9935818339601722, 0.9139785790286485, 0.9812313308817254, 0.9636989588157858]
#
#
# file_id:  25534 .txt
# ['Highlights', 'At a Glance', 'Chairman’s Statement']
# [0.9935730960631898, 0.9129263855733267, 0.9810450019082473]
#
#
# file_id:  25535 .txt
# ['Highlights', 'At a Glance', 'Chairman’s Statement', 'Business Review: Chief Executive Officer’s Statement']
# [0.9935550332751839, 0.9142247048161348, 0.9813647322942719, 0.9061157575291638]
#
#
# file_id:  25542 .txt
# ['Highlights', 'Chairman’s statement', 'Chief executive officer’s report']
# [0.9934134791419206, 0.9813388629832894, 0.9311323171377929]
#
#
# file_id:  25554 .txt
# ['Highlights', 'Our portfolio at a glance', 'Chairman’s statement', 'Chief Executive’s statement']
# [0.9935599724703551, 0.7793249963955803, 0.9807966809379253, 0.9801081244588373]
#
#
# file_id:  25555 .txt
# ['Highlights', 'Our portfolio at a glance', 'Chairman’s statement', 'Chief Executive’s statement']
# [0.9935619233979228, 0.7760920540131262, 0.9805475838584278, 0.9798831027834016]
#
#
# file_id:  25564 .txt
# []
# []
#
#
# file_id:  25575 .txt
# ['Financial and business highlights', 'Chairman’s Statement', 'Chief Executive’s Report']
# [0.6472922272295467, 0.981795081572219, 0.9563311431837918]
#
#
# file_id:  25592 .txt
# ['Highlights 2016', 'Chairman’s statement', 'Chief Executive’s statement']
# [0.9935778079052592, 0.9812265489445182, 0.9789017326688891]
#
#
# file_id:  25594 .txt
# ['start', 'ITV at a Glance', 'Chairman’s Statement', 'Chief Executive’s Review']
# [0.8774127416391305, 0.70015009657674, 0.9792598017849353, 0.9920126804540682]
#
#
# file_id:  25602 .txt
# ['Performance highlights', 'Chairman’s statement', 'Chief Executive Officer’s review']
# [0.9196486278689466, 0.9799054873372567, 0.9718049062117952]
#
#
# file_id:  25604 .txt
# ['Financial highlights', 'Chairman’s letter', 'Chief Executive’s letter']
# [0.8822720554006042, 0.8303374706962205, 0.9839878846405082]
#
#
# file_id:  25611 .txt
# ['Highlights', 'Chairman’s statement', 'Chief Executive’s review']
# [0.9935582237798765, 0.9819308090301146, 0.9924627540604251]
#
#
# file_id:  25630 .txt
# ['Financial Highlights', 'Chairman’s Statement', 'Chief Executive’s Review', 'Group Executive Committee']
# [0.8804077192998151, 0.9803096828345437, 0.9918879499077085, 0.5201964883514462]
#
#
# file_id:  25631 .txt
# ['Financial Highlights', 'Our Businesses at a glance', 'Chairman’s Statement', 'Chief Executive’s Review', 'Group Executive Committee']
# [0.8824717698208977, 0.7207766826092186, 0.9801741100591164, 0.9920906245177096, 0.5122363318993073]
#
#
# file_id:  25632 .txt
# ['Financial Highlights', 'Our Businesses at a Glance', 'Chairman’s Statement', 'Chief Executive’s Review', 'Group Executive Committee']
# [0.8819761657323875, 0.7208774646595804, 0.9803402145278576, 0.992050913451332, 0.529806451103976]
#
#
# file_id:  25633 .txt
# ['Financial Highlights', 'Our Businesses at a Glance', 'Chairman’s Statement', 'Chief Executive’s Review', 'Group Executive Committee']
# [0.881785171299867, 0.7223522703211129, 0.9801223474031963, 0.9925333362364879, 0.512601610466174]
#
#
# file_id:  25634 .txt
# ['Financial Highlights', 'Our Businesses at a Glance', 'Chairman’s Statement', 'Chief Executive’s Review', 'Group Executive Committee']
# [0.8819047516565405, 0.7202882385035279, 0.980020057764134, 0.9924388048741607, 0.5135606718454386]
#
#
# file_id:  25650 .txt
# ['Financial highlights from continuing operations', 'Chief Executive’s report', 'Chairman’s statement']
# [0.6880623744396668, 0.9559763279176303, 0.9806288757736946]
#
#
# file_id:  25660 .txt
# ['Business highlights', 'Jelf at a glance', 'Chairman’s statement', 'Group Chief Executive’s report']
# [0.9137651846758078, 0.9139739508486515, 0.9811955665174124, 0.9183719708174016]
#
#
# file_id:  25669 .txt
# ['KPIs and Highlights', 'Chairman’s Statement', 'Chief Executive Officer’s Review']
# [0.9575846907811397, 0.9810351617769426, 0.9736103954520334]
#
#
# file_id:  25684 .txt
# ['Financial Highlights', 'Chairman’s Statement', 'Chief Executive’s Introduction']
# [0.8828602921001723, 0.9807607681862258, 0.9789580596082031]
#
#
# file_id:  25685 .txt
# ['KPIs and Financial Highlights', 'Chairman’s Statement', 'Chief Executive’s Review']
# [0.8201641561778195, 0.981129057367365, 0.992734824013588]
#
#
# file_id:  25686 .txt
# ['KPIs and Financial Highlights', 'Chairman’s Statement', 'Chief Executive’s Review']
# [0.8205141591709739, 0.9813769208107864, 0.9928007090510891]
#
#
# file_id:  25687 .txt
# ['KPIs and Financial Highlights', 'Chairman’s Statement', 'Chief Executive’s Review']
# [0.8209348008553505, 0.9814182586878728, 0.9928244119192788]
#
#
# file_id:  25688 .txt
# ['KPIs and Highlights', 'Chairman’s Statement', 'Chief Executive Officer’s Review']
# [0.9575882578119332, 0.9811146626626771, 0.9734909304865749]
#
#
# file_id:  25695 .txt
# ['At a Glance', '2015 Highlights', 'Chairman’s Statement', 'Chief Executive Officer’s Report']
# [0.9121135430016272, 0.9934397836386037, 0.9811070734667269, 0.9298281404424195]
#
#
# file_id:  25696 .txt
# ['HIGHLIGHTS', 'Chairman’s Statement', 'Chief Executive’s Strategic Report']
# [0.9935803982536497, 0.9815132538042727, 0.9139893383209734]
#
#
# file_id:  26007 .txt
# ['Highlights', 'Chairman’s statement', 'Chief Executive’s']
# [0.9935430916934866, 0.981388522704879, 0.9966270097252335]
#
#
# file_id:  26008 .txt
# ['Chairman’s statement', 'Highlights', 'Chief Executive’s statement']
# [0.9818869332667021, 0.9934736031931906, 0.9809673081636406]
#
#
# file_id:  26011 .txt
# ['Highlights', 'Chairman’s and Chief Executive’s review', 'Jupiter at a glance', 'Chairman’s introduction']
# [0.993547224371747, 0.9970740998805361, 0.9126593371795002, 0.6806771136003521]
#
#
# file_id:  26012 .txt
# ['Highlights', 'Chairman’s introduction', 'Chief Executive’s review']
# [0.9936160205256875, 0.7454593551859453, 0.9928118129282527]
#
#
# file_id:  26068 .txt
# ['Highlights 2016', 'Chairman’s statement', 'At a glance', 'Chief Executive Officer’s review']
# [0.9934889895177758, 0.9814453848139785, 0.9107957078750247, 0.9733720874360993]
#
#
# file_id:  26071 .txt
# ['Chairman’s Statement', 'Financial Highlights', 'Chief Executive’s Report']
# [0.9818725787883773, 0.8813910849751971, 0.955303814628151]
#
#
# file_id:  26072 .txt
# ['Financial & operational highlights', 'At a glance', 'Chairman’s statement', 'Chief Executive’s review']
# [0.919442626135445, 0.9135286364340379, 0.9814383576881069, 0.992030318464505]
#
#
# file_id:  26074 .txt
# ['At a glance we create value', 'Chairman’s Statement', 'Chief Executive Officer’s Operating Review']
# [0.6229737670706186, 0.9811927886149607, 0.9059431862805364]
#
#
# file_id:  26089 .txt
# ['At a Glance', 'Chairman’s Statement', 'Chief Executive’s Review']
# [0.9133895052650042, 0.9814503089314744, 0.9925440332086164]
#
#
# file_id:  26092 .txt
# ['KAZ Minerals at a glance', 'Chairman’s statement', 'Chief Executive’s review']
# [0.7924913446013784, 0.9808830839264484, 0.9924650608750633]
#
#
# file_id:  26093 .txt
# ['Our business at a glance', 'Chairman’s statement']
# [0.7304837999385589, 0.9815672446161728]
#
#
# file_id:  26142 .txt
# ['Highlights in', 'At a Glance', 'Chairman’s Statement', 'Chief Executive’s Review']
# [0.9935770428398677, 0.9131967575001699, 0.9815025510744072, 0.9922480527217293]
#
#
# file_id:  26146 .txt
# ['Financial highlights', 'Chairman’s statement', 'Chief Executive’s strategic review', 'Chairman’s introduction']
# [0.8756536874068209, 0.9804215453457614, 0.962046183101503, 0.666057708636252]
#
#
# file_id:  26147 .txt
# ['Kingﬁ sher at a glance', 'Chairman’s statement']
# [0.7936982227079759, 0.9813750165430629]
#
#
# file_id:  26171 .txt
# ['Financial & Operational Highlights', 'Chairman’s Statement', 'Chief Executive Officer’s Review']
# [0.9194367406918402, 0.9816532770921486, 0.9741635925561294]
#
#
# file_id:  26174 .txt
# ['Chairman’s statement', 'Group at a glance', 'Chief Executive’s review']
# [0.9815930802075006, 0.8047812034570813, 0.9919227522446219]
#
#
# file_id:  26180 .txt
# ['Financial highlights', 'At a glance', 'Chairman’s statement', 'Chief Executive’s review']
# [0.8831008404084966, 0.9132714304269508, 0.9813583959905416, 0.9926632066970642]
#
#
# file_id:  26182 .txt
# ['Highlights 2016', 'Lamprell at a glance', 'Executive Chairman’s statement', 'Chief Executive’s review']
# [0.9934510738794347, 0.7054459806934377, 0.9886969859732601, 0.9925509192104474]
#
#
# file_id:  26229 .txt
# ['Highlights', 'Chairman’s statement', 'Group Chief Executive’s review']
# [0.9935317753567926, 0.9819023677385261, 0.9825646918246818]
#
#
# file_id:  26230 .txt
# ['Highlights', 'Chairman’s statement', 'Group Chief Executive’s review', 'Chairman’s Letter']
# [0.9935188125616091, 0.9808884416991257, 0.9821087774967482, 0.735045112686049]
#
#
# file_id:  26232 .txt
# ['start', 'Chairman’s Statement', 'Highlights and changes to our report', 'Group Chief Executive’s Review', 'Letter from the Chairman']
# [0.8770090436020292, 0.9815629686967997, 0.5395381002981285, 0.9824457506429715, 0.7103604536967626]
#
#
# file_id:  26233 .txt
# ['start', 'Chairman’s statement', 'Highlights for', 'Group chief executive’s review', 'Letter from the Chairman']
# [0.8771601613760646, 0.9814243658796653, 0.9933353206110218, 0.9821501030480412, 0.7020464539569895]
#
#
# file_id:  26236 .txt
# ['start', 'Chairman’s statement', 'Our business at a glance', 'Group Chief Executive Officer Q&A', 'Letter from the Chairman']
# [0.8774571558098286, 0.9814629437896597, 0.7258575177074382, 0.9766539601536712, 0.6964004233413216]
#
#
# file_id:  26280 .txt
# ['Financial and Operating Highlights', 'Chairman’s Statement', 'Chief Executive Officer’s Review']
# [0.5957314318338284, 0.9817668295507155, 0.9743646208385429]
#
#
# file_id:  26340 .txt
# ['Financial Highlights', 'Chairman’s Statement', 'Chief Executive’s report']
# [0.8824669227567239, 0.9817159460954984, 0.9550391381000568]
#
#
# file_id:  26341 .txt
# ['Highlights', 'Chairman’s Statement', 'Chief Executive’s report']
# [0.9934265419171749, 0.9815088768564239, 0.9547513699297151]
#
#
# file_id:  26342 .txt
# ['start', 'Highlights', 'Chairman’s Statement', 'Chief Executive’s report']
# [0.8786235893719255, 0.992797003828947, 0.9796909415069814, 0.9510271004378471]
#
#
# file_id:  26358 .txt
# ['At a glance', 'Chairman’s statement', 'Group Chief Executive’s review']
# [0.9090445644273971, 0.9801127510026255, 0.9943861796051137]
#
#
# file_id:  26360 .txt
# ['start', 'Group at a glance', 'Chairman’s statement', 'Group Chief executive’s review']
# [0.8814841846512156, 0.7936966846745279, 0.9777563542970557, 0.9786838425841907]
#
#
# file_id:  26361 .txt
# ['Group at a glance', 'Chairman’s statement', 'Group Chief Executive’s review']
# [0.8157741172293539, 0.9815589198653211, 0.9824870980477026]
#
#
# file_id:  26362 .txt
# ['Highlights and strategic priorities', 'Chairman’s statement', 'Group Chief Executive’s review']
# [0.8892785173494512, 0.9814762300914444, 0.9822444455166588]
#
#
# file_id:  26363 .txt
# ['Group highlights', 'Divisional highlights', "Chairman's statement", "Group Chief Executive's review", 'Letter from the Chairman']
# [0.9218811733558165, 0.9162002774283015, 0.98079169831277, 0.9817360274040732, 0.7112413604067077]
#
#
# file_id:  26453 .txt
# ['Financial Highlights', 'Chairman’s Statement', 'Chief Executive’s Review']
# [0.8838063580404486, 0.9818750037770217, 0.9930342309611457]
#
#
# file_id:  26455 .txt
# ['Chairman’s Statement', 'Chief Executive’s Review']
# [0.9819288919529033, 0.9927736141976463]
#
#
# file_id:  26457 .txt
# ['Financial Highlights', 'Chairman’s Statement', 'Chief Executive’s Review']
# [0.8837434605061238, 0.9816480162344501, 0.9926647166072701]
#
#
# file_id:  26460 .txt
# ['Financial highlights', 'Chairman’ s statement', 'Chief Executive’ s review']
# [0.8840016326936544, 0.9813760993168623, 0.9927732789163237]
#
#
# file_id:  26464 .txt
# ['start']
# [0.8780812765975943]
#
#
# file_id:  26465 .txt
# ['start', 'Highlights', 'Group at a glance', 'Chairman’s statement', 'Chief Executive’s review']
# [0.8765881821768776, 0.9934066892700107, 0.8142414327766951, 0.9791717205557854, 0.9918846935750153]
#
#
# file_id:  26466 .txt
# ['Highlights', 'Group at a glance', 'Chairman’s statement', 'Chief Executive’s review']
# [0.9934898641376474, 0.8146819729910726, 0.979724359207074, 0.9920536418234592]
#
#
# file_id:  26467 .txt
# ['start']
# [0.8824504876139175]
#
#
# file_id:  26468 .txt
# ['start', 'Financial highlights', 'Operational highlights', 'Chairman’s statement', 'Chief Executive’s statement', 'Executive management team']
# [0.8768246111012363, 0.8806280810964069, 0.8882952306382488, 0.9796481917116774, 0.9775480526253356, 0.5217300042832551]
#
#
# file_id:  26469 .txt
# ['Financial highlights', 'Operational highlights', 'Group at a glance', 'Chairman’s statement', 'Chief Executive’s statement', 'Executive management team']
# [0.8812539141960739, 0.8889953526911931, 0.8145361298425945, 0.9784581299539339, 0.9778522775155418, 0.525532395957558]
#
#
# file_id:  26470 .txt
# ['start', 'Highlights', 'Chairman’s statement', 'Chief Executive’s statement', 'Executive management team']
# [0.8770326133402729, 0.9934303804845119, 0.9809827180764907, 0.9805979552993539, 0.524799933670146]
#
#
# file_id:  26471 .txt
# ['start', 'Highlights', 'Chairman’s statement', 'Chief Executive’s statement', 'Executive management team']
# [0.8772589649959806, 0.9934607646624327, 0.9811437770595819, 0.9804966439302937, 0.5222661952057137]
#
#
# file_id:  26473 .txt
# ['Business and financial highlights', 'Chairman’s statement', 'Chief Executive’s review']
# [0.7670188800177259, 0.981571922687929, 0.9928170366185687]
#
#
# file_id:  26474 .txt
# ['Financial Highlights', 'Chairman’s Statement', 'Chief Executive’s Review']
# [0.8835293469903477, 0.9814793275909209, 0.9927283633601658]
#
#
# file_id:  26475 .txt
# ['Financial Highlights', 'Chairman’s Statement', 'Chief Executive’s Review']
# [0.8821685251142461, 0.9811752357058889, 0.9926339798934652]
#
#
# file_id:  26482 .txt
# ['Performance Highlights', 'Chairman’s Statement']
# [0.9196115079775204, 0.9793083181573091]
#
#
# file_id:  26492 .txt
# ['Highlights', 'Chairman’s statement', 'Chief Executive’s review', 'Executive Leadership Team']
# [0.9935400681633059, 0.9817563955323948, 0.9922034977509511, 0.5779529194798564]
#
#
# file_id:  26514 .txt
# ['Highlights 2016', 'Chairman’s Statement', 'Group Chief Executive’s Review']
# [0.9935160763754488, 0.9813287762408237, 0.9826549506084745]
#
#
# file_id:  26599 .txt
# ['Highlights for 2014', 'Chairman’s Statement', 'Chief Executive’s Report']
# [0.9935438294132253, 0.9815621739792073, 0.9546710063621194]
#
#
# file_id:  26600 .txt
# ['Highlights for 2015', 'Chairman’s Statement', 'Chief Executive’s Report']
# [0.9935438294132253, 0.9815725026866444, 0.9550378823340365]
#
#
# file_id:  26601 .txt
# ['Highlights for 2016', 'Chairman’s Statement', 'Chief Executive’s Report']
# [0.9935438294132253, 0.9815713868942549, 0.9550463972819522]
#
#
# file_id:  26617 .txt
# []
# []
#
#
# file_id:  26618 .txt
# ['Highlights', 'Chairman’s Review', 'Chief Executive’s Review']
# [0.9924389293958493, 0.796088268337431, 0.9917152904274686]
#
#
# file_id:  26621 .txt
# ['start']
# [0.8865638289158732]
#
#
# file_id:  26624 .txt
# ['Highlights', 'Chairman’s statement', 'Chief Executive Officer’s Review']
# [0.9935505416359824, 0.9814982160355633, 0.9719562200910493]
#
#
# file_id:  26654 .txt
# ['financial highlights', 'manx telecom at a glance', 'chairman’s statement', 'executive team']
# [0.8838347738977327, 0.7950423590063749, 0.9809208530411683, 0.6540018368864522]
#
#
# file_id:  26666 .txt
# ['At a glance', 'Chairman’s statement', 'Chief Executive’s strategic']
# [0.9129205400915739, 0.9815243051314445, 0.9856118733548854]
#
#
# file_id:  26668 .txt
# ['At a Glance', 'Chairman’s Statement', 'Chief Executive’s Statement']
# [0.9128737335841942, 0.9808556232243298, 0.9800019579941209]
#
#
# file_id:  26763 .txt
# ['Highlights', 'Chairman’s statement', 'Chief executive’s review']
# [0.9935659148620866, 0.9817236580082845, 0.9928352119450714]
#
#
# file_id:  26768 .txt
# ['Highlights', 'Chairman’s statement', 'Chief executive’s review']
# [0.9934472179386272, 0.9816005287759639, 0.992513734405686]
#
#
# file_id:  26771 .txt
# ['Highlights', 'Chairman’s statement', 'Chief Executive’s review']
# [0.9935647227328712, 0.9812762133332871, 0.9924998108117588]
#
#
# file_id:  26772 .txt
# ['Highlights', 'Year at a glance', 'Chairman’s statement', 'Chief Executive’s review']
# [0.993568129010446, 0.7096777271757763, 0.9810073634241424, 0.992469216301246]
#
#
# file_id:  26773 .txt
# ['Highlights', 'At a glance', 'Chairman’s statement', 'Chief Executive’s review']
# [0.9934871225045332, 0.913168630168914, 0.9807940950114248, 0.9920638530792057]
#
#
# file_id:  26813 .txt
# ['Financial Highlights']
# [0.8803453607182602]
#
#
# file_id:  26821 .txt
# ['At a glance', 'Chairman’s statement', 'Executive review', 'Chairman’s introduction']
# [0.9126449446914041, 0.9813506412989277, 0.8827305384816627, 0.6848081902757766]
#
#
# file_id:  26822 .txt
# ['Chairman’s Statement', 'Chief Executive’s Review']
# [0.9810881754799535, 0.9921730908595985]
#
#
# file_id:  26823 .txt
# ['start']
# [0.8801785866234871]
#
#
# file_id:  26830 .txt
# ['Chairman’s statement', 'Chief Executive’s strategy overview']
# [0.9808972464670087, 0.969429656987106]
#
#
# file_id:  26844 .txt
# ['Chairman', 'Mr S G Young Chief Executive']
# [0.9497650987035913, 0.9448925119391536]
#
#
# file_id:  26899 .txt
# ['Mercia at a glance', 'Chairman’s statement', 'Chief executive officer review']
# [0.9136032141946762, 0.9801541404594967, 0.9733430178776058]
#
#
# file_id:  26904 .txt
# ['start', 'MERLIN AT A GLANCE', 'CHAIRMAN’S STATEMENT', 'CHIEF EXECUTIVE’S REPORT']
# [0.8767944959650982, 0.7896372587028562, 0.9804205959007372, 0.9520580229819247]
#
#
# file_id:  26939 .txt
# ['Financial Highlights', 'Chairman’s Statement', "Chief Executive's Review", 'Executive Team']
# [0.8832516853113429, 0.9815192092790137, 0.9928746854792436, 0.7048747435501163]
#
#
# file_id:  26953 .txt
# ['Executive Chairman’s statement', 'Executive Chairman’s introduction']
# [0.9892304040509086, 0.8470014755989967]
#
#
# file_id:  27013 .txt
# ['Chairman’s statement', 'Mitchells & Butlers at a glance', 'Chief Executive’s statement']
# [0.9817767277778744, 0.7086538523425374, 0.9810368150855944]
#
#
# file_id:  27029 .txt
# ['Mitie at a glance', 'Chairman’s statement', 'Chief Executive’s strategy overview', 'Chairman ’ s intr oduc tion to']
# [0.7097055929235215, 0.9812536797654787, 0.9696862328003679, 0.8460737441278141]
#
#
# file_id:  27070 .txt
# ['Our business at a glance', 'Chairman’s introduction', 'Chief Executive’s Q & A']
# [0.732239318708115, 0.7447964875729071, 0.9965122967592982]
#
#
# file_id:  27130 .txt
# ['Financial and operational highlights', 'Chairman’s statement', 'Chief Executive Officer’s review', 'Chairman’s letter to shareholders']
# [0.5819181742111408, 0.9805848480509085, 0.9730163123353833, 0.6226464880468484]
#
#
# file_id:  27131 .txt
# ['Chairman’s statement', 'Chief Executive’s statement']
# [0.9812060255756845, 0.9794635013116736]
#
#
# file_id:  27140 .txt
# ['Chairman’s Statement', 'Chief Executive’s Review']
# [0.9816718594874811, 0.9928449064151996]
#
#
# file_id:  27212 .txt
# ['Highlights', 'Chairman’s Statement', 'Chief Executive’s Review', 'Executive Management Team']
# [0.9934692674961366, 0.9815062007039718, 0.9927500757152461, 0.5006565288681785]
#
#
# file_id:  27213 .txt
# ['Operating and financial highlights', 'Chairman’s statement']
# [0.7153789127892676, 0.9817637725168735]
#
#
# file_id:  27214 .txt
# ['Highlights', 'At a glance', 'Chairman’s statement', 'Chief Executive Officer’s statement']
# [0.9935866616724319, 0.9134850463742485, 0.9813285212384593, 0.9642022804743363]
#
#
# file_id:  27217 .txt
# ['Financial highlights', 'Chairman’s letter', 'Group Chief Executive’s review', 'Our strategy at a glance', 'Chairman’s introduction']
# [0.8812508145329225, 0.8247716790095188, 0.98254428123096, 0.7539757473882707, 0.611115158932072]
#
#
# file_id:  27218 .txt
# ['start', 'At a glance', 'Chairman’s statement', 'Chief Executive’s review']
# [0.8758407089250606, 0.9121628431834691, 0.9811721525988064, 0.992454782434232]
#
#
# file_id:  27282 .txt
# ['Highlights of 2006']
# [0.9936046698452433]
#
#
# file_id:  27283 .txt
# ['Highlights of 2007', 'Chairman’s Statement', 'Chief Executive’s Review']
# [0.9935223507004585, 0.9816806178348878, 0.9928119847151293]
#
#
# file_id:  27375 .txt
# ['Highlights', 'SPARK at a glance', 'Chief Executive Officer’s report']
# [0.9935504187170513, 0.9141335426081477, 0.9317243965477867]
#
#
# file_id:  27377 .txt
# ['start', 'Chief Executive Officer’s report']
# [0.8771183201930112, 0.9323458983285215]
#
#
# file_id:  27381 .txt
# ['Financial and operational highlights', 'At a glance', 'Chairman’s statement', 'Chief Executive Officer’s statement']
# [0.596712834489448, 0.9135567398890179, 0.9816481669992997, 0.9665722497887387]
#
#
# file_id:  27418 .txt
# ['Highlights', 'At a glance', 'Chairman’s statement', 'Group Chief Executive’s statement']
# [0.99352981535297, 0.9137433536886982, 0.9815483623034823, 0.9612236814599454]
#
#
# file_id:  27440 .txt
# ['Financial and Operational Highlights', 'Chairman’s Statement', 'Q&A with the Chief Executive']
# [0.5950252570041105, 0.9809901931891432, 0.9966064108648212]
#
#
# file_id:  27512 .txt
# ['Highlights', 'Chairman’s statement', 'In discussion with the Chief Executive', 'Group at a glance', 'Chief Executive’s operational review']
# [0.9935486318850418, 0.9817017086403568, 0.9917970862465179, 0.8080981518916657, 0.9461590132715659]
#
#
# file_id:  27513 .txt
# ['Highlights', 'Chief Executive Officer’s Report']
# [0.993580902649165, 0.9320637485997217]
#
#
# file_id:  27516 .txt
# ['Highlights and key', 'Novae at a glance', 'Chairman’s statement', 'Chief Executive’s']
# [0.8946278921758987, 0.9129244196570526, 0.9812314209281668, 0.9965508161631674]
#
#
# file_id:  27517 .txt
# ['Highlights and key performance indicators', 'Novae at a glance', 'Chairman’s statement', 'Chief Executive’s statement']
# [0.5605127388445823, 0.9138048105594537, 0.9811880283061328, 0.9808425296100505]
#
#
# file_id:  27518 .txt
# ['Highlights and key performance', 'Novae at a glance', 'Chairman’s statement', 'Chief Executive’s statement']
# [0.7414348971450108, 0.9131611142193591, 0.9811857961165028, 0.9806419199861482]
#
#
# file_id:  27519 .txt
# ['Novae at a glance', 'Chief Executive’s']
# [0.9133137927676984, 0.9966778232220639]
#
#
# file_id:  27522 .txt
# ['Financial highlights', 'Chairman’s statement', 'Chief executive’s statement']
# [0.883266238907013, 0.9816564335850473, 0.9814105216802124]
#
#
# file_id:  27523 .txt
# ['Financial highlights', 'Chairman’s statement', 'Chief executive’s statement']
# [0.8838391762044253, 0.9814922214847233, 0.9807740799542742]
#
#
# file_id:  27524 .txt
# ['start', 'Financial highlights', 'Chairman’s statement', 'Chief executive’s statement']
# [0.8774551335793052, 0.880149586211679, 0.9810252903864141, 0.979823384398635]
#
#
# file_id:  27525 .txt
# ['Financial highlights', 'Chairman’s statement', 'Chief executive’s statement']
# [0.8839377176075666, 0.9815504705431312, 0.9806592666085303]
#
#
# file_id:  27531 .txt
# ['Highlights', 'Chairman’s Statement', 'Chief Executive’s Review']
# [0.9935084049439602, 0.9806490445003839, 0.9925116289803895]
#
#
# file_id:  27532 .txt
# ['start', 'Highlights', 'Chairman’s Statement', 'Chief Executive’s Review']
# [0.8772896202321467, 0.9934519896525634, 0.9804105916089015, 0.9921808697566709]
#
#
# file_id:  27539 .txt
# ['Financial Highlights', 'Chairman’s Statement', 'Chief Executive’s Statement', 'Execution']
# [0.8835184412635049, 0.9816323129368963, 0.9816418440243567, 0.9285211076525455]
#
#
# file_id:  27540 .txt
# ['Financial Highlights', 'Chairman’s Statement', 'Chief Executive’s Statement', 'Execution']
# [0.8835627652718909, 0.9816719846883308, 0.9816332624489452, 0.9289981403081313]
#
#
# file_id:  27541 .txt
# ['Financial Highlights', 'Chairman’s Statement', 'Chief Executive’s Statement', 'Execution']
# [0.883108538122684, 0.9814746640786989, 0.9810306284353443, 0.9280619008090764]
#
#
# file_id:  27543 .txt
# ['Financial Highlights', 'Chairman’s Statement', 'Chief Executive’s Statement', 'Execution']
# [0.8836567444417093, 0.9814951079923909, 0.9811034164549228, 0.9287669450049018]
#
#
# file_id:  27544 .txt
# ['Financial Highlights', 'Chairman’s Statement', 'Chief Executive’s Statement', 'Execution']
# [0.8836471058571976, 0.9814632671237096, 0.9810435436316294, 0.9294453136870603]
#
#
# file_id:  27665 .txt
# ['Financial Highlights', 'Chairman’s Statement', 'Chief Executive’s Statement']
# [0.8835814831360306, 0.981463096046202, 0.9809633523161057]
#
#
# file_id:  27666 .txt
# ['Financial Highlights', 'Chairman’s Statement', 'Chief Executive’s Statement']
# [0.8840131741072114, 0.981563183112166, 0.9811935470130418]
#
#
# file_id:  27669 .txt
# ['start']
# [0.8806418202455798]
#
#
# file_id:  27670 .txt
# ['Highlights', 'Our business at a glance', 'Chairman’s statement', 'Group Chief Executive’s statement', 'Chairman’s introduction']
# [0.9935573360127766, 0.7303125032968978, 0.9814910753054422, 0.9622882900405332, 0.5416681389933511]
#
#
# file_id:  27671 .txt
# ['Our business at a glance', 'Chairman’s statement', 'Group Chief Executive’s statement', 'Group Executive Committee']
# [0.7303144293189564, 0.9806114702336896, 0.9602114521209023, 0.5127976120495664]
#
#
# file_id:  27672 .txt
# ['Our business at a glance', 'Chairman’s statement', 'Group Chief Executive’s statement', 'Group Chief Executive’s Q&A']
# [0.7317709206226379, 0.9791354827903846, 0.9569180145609414, 0.9825110080974649]
#
#
# file_id:  27673 .txt
# ['Our business at a glance', 'Chairman’s statement', 'Group Chief Executive’s statement', 'Group Chief Executive’s Q&A']
# [0.7303073546414327, 0.9800812949976204, 0.9587887310897951, 0.9833583071618915]
#
#
# file_id:  27675 .txt
# ['Group at a glance', 'Chairman’s message to shareholders', 'Chief Executive’s review']
# [0.8173906147247461, 0.7729682825280451, 0.9928948536512688]
#
#
# file_id:  27676 .txt
# ['At a glance', 'Chairman’s message to shareholders', 'Chief Executive’s review']
# [0.9129358033916797, 0.7763926767999719, 0.9929610356513368]
#
#
# file_id:  27684 .txt
# ['At a Glance', 'Chairman’s Statement', 'Chief Executive’s Review']
# [0.9140189878954906, 0.9811886340206238, 0.9920572591864015]
#
#
# file_id:  27686 .txt
# ['At a glance', 'Chairman’s statement', 'Chief Executive’s report', 'Chairman’s introduction']
# [0.9127245713205034, 0.981440586165742, 0.9544194910690612, 0.7070779590286148]
#
#
# file_id:  27690 .txt
# ['Performance Highlights', 'Chairman’s Statement', 'Chief Executive’s Statement']
# [0.9194994139550972, 0.9816152134507901, 0.98130484718925]
#
#
# file_id:  27699 .txt
# ['Highlights', 'Chairman’s statement', 'Chief Executive’s review']
# [0.9933596039979943, 0.9806048757267984, 0.9919048026122269]
#
#
# file_id:  27700 .txt
# ['Chairman’s statement', 'Chief Executive Officer’s review']
# [0.9814598624274107, 0.9735449568027862]
#
#
# file_id:  27719 .txt
# ['Group financial highlights', 'Chairman’s statement', 'Chief executive’s review']
# [0.7816081090470847, 0.981572584333437, 0.9928941617457798]
#
#
# file_id:  27720 .txt
# ['Group financial highlights', "Chairman's statement", "Chief executive's review"]
# [0.7825675932839675, 0.9817397212811462, 0.9929374274663537]
#
#
# file_id:  27779 .txt
# ['Highlights', 'Chairman’s Statement', 'Chief Executive’s Review']
# [0.9935769672282833, 0.9813873324297473, 0.9927486983298688]
#
#
# file_id:  27876 .txt
# ['start', 'Chief Executive Ofﬁ cer’s review']
# [0.8825130556491015, 0.9522289428453109]
#
#
# file_id:  27878 .txt
# ['Highlights', 'Chairman’s statement', 'Chief Executive’s review']
# [0.993576306493598, 0.9819022307339189, 0.9929694576963576]
#
#
# file_id:  27879 .txt
# ['Highlights', 'Chairman’s Statement', 'Chief Executive’s Review']
# [0.993571593557098, 0.9818114257897057, 0.9930123066849147]
#
#
# file_id:  27880 .txt
# ['Highlights', 'Chairman’s statement', 'Chief Executive’s review']
# [0.9935844826359207, 0.9816916825463397, 0.9929826492529953]
#
#
# file_id:  27886 .txt
# ['Highlights', 'Chairman’s statement', 'Group at a glance', 'Chief Executive’s review']
# [0.9935169497996641, 0.9814091679665116, 0.8124374335762369, 0.9927251600911775]
#
#
# file_id:  27889 .txt
# ['Highlights', 'Chairman’s statement', 'Group at a glance', 'Chief Executive’s review']
# [0.9935628351919584, 0.9814595955127006, 0.8124298391239837, 0.9927354899769169]
#
#
# file_id:  27913 .txt
# ['Chairman’s statement', 'Chief Executive’s review']
# [0.9819895092447762, 0.9928239181814486]
#
#
# file_id:  27914 .txt
# ['The Paragon Group of Companies PLC Financial highlights', 'Chairman’s statement', 'Chief Executive’s review']
# [0.5750962929080814, 0.9816761546005641, 0.9929369783742954]
#
#
# file_id:  27915 .txt
# ['Financial highlights', 'Chairman’s statement', 'Chief Executive’s review']
# [0.8837988064829528, 0.9818912407732682, 0.9929946846982279]
#
#
# file_id:  27916 .txt
# ['Financial highlights', 'Chairman’s statement', 'Chief Executive’s review']
# [0.8838862894789168, 0.981867063237706, 0.9929898779538839]
#
#
# file_id:  27917 .txt
# ['Financial highlights', 'Chairman’s statement', 'Chief Executive’s review']
# [0.8840247145230932, 0.9817098266113021, 0.9929936249611523]
#
#
# file_id:  27918 .txt
# ['Financial highlights', 'Chairman’s statement', 'Chief Executive’s review']
# [0.8838219619329435, 0.9818786381416746, 0.9929602719315673]
#
#
# file_id:  27935 .txt
# ['At a glance', 'Chairman’s statement', 'Chief Executive’s review']
# [0.9137964630871316, 0.9812502303989475, 0.9926505174681849]
#
#
# file_id:  27936 .txt
# ['At a glance', 'Chairman’s statement', 'Chief Executive’s review']
# [0.9144764583438371, 0.9814290161124591, 0.9927247444797364]
#
#
# file_id:  27937 .txt
# ['start', 'At a Glance', 'Chairman’s Statement', 'Chief Executive’s Review']
# [0.8781057464547528, 0.9112423675654158, 0.9805478690481544, 0.9925098361515288]
#
#
# file_id:  27939 .txt
# ['Chairman’s Statement', 'Chief Executive’s Review']
# [0.9802066867826931, 0.9922821143617365]
#
#
# file_id:  27954 .txt
# ['Partnership at a glance', 'Chairman’s statement', 'Chief Executive Officer’s statement', 'An introduction from our Chairman', 'An introduction from our Committee Chairman']
# [0.7968248387323734, 0.9813833213669497, 0.9666135994923599, 0.6783892650180601, 0.503956227722955]
#
#
# file_id:  28079 .txt
# ['Financial Highlights', "Chairman's Statement"]
# [0.8830466820924232, 0.9810450088925413]
#
#
# file_id:  28080 .txt
# ['2016 Financial Highlights', 'At a Glance', 'Chairman’s Statement', 'Chief Executive’s Statement']
# [0.883118108630969, 0.9134237697779904, 0.981258660694199, 0.9786372698616456]
#
#
# file_id:  28084 .txt
# ['Highlights', 'Chairman’s Statement', 'Chief Executive Officer’s']
# [0.9932687251391837, 0.9806827587835516, 0.9893990052301]
#
#
# file_id:  28085 .txt
# ['Highlights', 'At a glance', 'Chairman’s statement', 'Chief Executive’s statement']
# [0.9934721092898088, 0.9105033123561906, 0.9806420358341689, 0.9776397274094027]
#
#
# file_id:  28122 .txt
# ['Financial and operational highlights', 'Chairman’s Statement', 'Chief Executive’s Review']
# [0.5963709375172833, 0.981794303387474, 0.9925788032897721]
#
#
# file_id:  28128 .txt
# ['start', 'Chief Executive Officer’s review']
# [0.8785423892993239, 0.9690077240525243]
#
#
# file_id:  28142 .txt
# ['Highlights', 'At a Glance', 'Chairman’s Statement', 'Chief Executive’s Review']
# [0.9935710103544885, 0.9138559906935114, 0.9816152134507901, 0.9928831967826224]
#
#
# file_id:  28165 .txt
# ['Polar Capital at a glance', 'Our funds at a glance', 'Chairman’s statement', 'Chief Executive’s statement']
# [0.7959451368371928, 0.7862763205879889, 0.981561574937279, 0.9810478729995676]
#
#
# file_id:  28166 .txt
# ['Polar Capital at a glance', 'Our funds/strategies at a glance', 'Chairman’s statement', 'Chief Executive’s statement']
# [0.7960438399248363, 0.7220424601303916, 0.9815466642981173, 0.9809170233972446]
#
#
# file_id:  28167 .txt
# ['Polar Capital at a glance', 'Our funds/strategies at a glance', 'Chairman’s statement', 'Chief Executive’s statement']
# [0.7963146328422248, 0.7209206772723055, 0.9814836857737587, 0.9807667840542011]
#
#
# file_id:  28168 .txt
# ['Polar Capital at a glance', 'Our funds/strategies at a glance', 'Chairman’s statement', 'Chief Executive’s statement']
# [0.7958217690614575, 0.7231660022297349, 0.9815170855794506, 0.9808033284905402]
#
#
# file_id:  28169 .txt
# ['Polar Capital at a Glance', 'Chairman’s Statement', 'Chief Executive’s Report']
# [0.7943294423954217, 0.9815285574728784, 0.9542578247989896]
#
#
# file_id:  28170 .txt
# ['Polar Capital at a Glance', 'Our funds/strategies at a Glance', 'Chairman’s Statement', 'Chief Executive’s Report']
# [0.7958414175420998, 0.7242975905369591, 0.9817522569980537, 0.9544795373804725]
#
#
# file_id:  28171 .txt
# ['Polar Capital at a Glance', 'Chairman’s Statement', 'Chief Executive’s Report']
# [0.7968415332694988, 0.9815937478935043, 0.9541778313632435]
#
#
# file_id:  28172 .txt
# ['start', 'Polar Capital at a Glance', 'Chairman’s Statement', 'Chief Executive’s Report']
# [0.8774128529177796, 0.7934036428876998, 0.9813390231176282, 0.9533598921772091]
#
#
# file_id:  28173 .txt
# ['Highlights', 'Chairman’s Statement', 'At a Glance', 'Chief Executive’s Report']
# [0.9935796089038126, 0.9818525257536508, 0.9115952354533838, 0.9543676258261797]
#
#
# file_id:  28201 .txt
# ['Chairman’s Introduction', 'Polypipe at a Glance', 'Chief Executive’s Review']
# [0.7418645549121677, 0.9113233156745858, 0.9927747312661056]
#
#
# file_id:  28204 .txt
# ['Highlights: Porta at a glance', 'Chairman’s Statement', 'Chief Executive’s Business Review']
# [0.960305713994736, 0.9814609780107919, 0.9574969211610636]
#
#
# file_id:  28215 .txt
# ['start', 'Chairman’s statement', 'President & Chief Executive', 'Strategy at a glance', 'Deputy Chief Executive Officer &']
# [0.8761436265461573, 0.9805507277520822, 0.9273432206830163, 0.7515584336257644, 0.9871920051970646]
#
#
# file_id:  28242 .txt
# ['At a glance', 'Chairman’s statement', "Chief Executive's review", 'Chairman’s introduction']
# [0.9135970535351506, 0.981340688222798, 0.9927998473713563, 0.6786996461868792]
#
#
# file_id:  28246 .txt
# ['Chairman’s Overview', 'Business at a Glance', 'Chief Executive Officer’s Review', 'Chairman’s Introduction']
# [0.8170479713657807, 0.7239335169873178, 0.9712743507557019, 0.5687085714592411]
#
#
# file_id:  28327 .txt
# ['Operational and Financial Highlights', 'Produce Investments at a Glance', 'Chairman’s Statement', 'Chief Executive’s Report']
# [0.7171429823589823, 0.7076435956437546, 0.9812608844039995, 0.9537678568685733]
#
#
# file_id:  28340 .txt
# ['Highlights of the year', 'Chairman’s statement', 'Chief Executive’s statement']
# [0.9265561878862397, 0.9814879985312142, 0.9807335759967454]
#
#
# file_id:  28341 .txt
# ['Financial highlights', 'Chairman’s statement', 'Chief Executive’s review']
# [0.8838635023135418, 0.9818940845899652, 0.9930526585569002]
#
#
# file_id:  28342 .txt
# ['Financial highlights', 'Chairman’s statement', 'Chief Executive’s review']
# [0.883713952613819, 0.9818215553556746, 0.9929528813199984]
#
#
# file_id:  28404 .txt
# ['Chairman’s statement', 'Chief Executive’s review']
# [0.9815999173894978, 0.9922340359452875]
#
#
# file_id:  28405 .txt
# ['Our business at a glance', 'Chairman’s statement', 'Chief Executive’s review']
# [0.7286635732422183, 0.9813819074219526, 0.9922606089714339]
#
#
# file_id:  28406 .txt
# ['Chairman’s statement', 'Chief Executive’s review', 'Letter from Chairman of']
# [0.9796156181417366, 0.9918446112336151, 0.7050852539181977]
#
#
# file_id:  28407 .txt
# ['start', 'business at a glance', 'Chairman’s statement', 'Chief Executive’s review', 'Letter from Chairman of the']
# [0.8798695347086156, 0.7037059132575179, 0.9791992740564518, 0.9918892261964622, 0.6699602658773943]
#
#
# file_id:  28408 .txt
# ['start', 'At a glance', 'Chairman’s statement', 'Chief Executive’s review', 'Chairman’s overview']
# [0.8841745808254111, 0.8936201445813963, 0.9764036918040354, 0.9909950567554384, 0.6524221436502862]
#
#
# file_id:  28410 .txt
# ['Highlights', 'At a glance', 'Chief Executive’s review']
# [0.9934967602937147, 0.9130826763338311, 0.9926847530013511]
#
#
# file_id:  28411 .txt
# ['At a glance', 'Introduction from the Chairman']
# [0.9136756199572758, 0.5862834196402306]
#
#
# file_id:  28414 .txt
# ['start', 'Group Financial Highlights', 'Chairman’s Statement', 'Group Chief Executive’s Review']
# [0.8775951840605012, 0.7764330405347354, 0.9811550572028458, 0.9824227694771197]
#
#
# file_id:  28415 .txt
# ['start', 'Group Financial Highlights', 'Chairman’s Statement', 'Group Chief Executive’s Review']
# [0.8782805957362015, 0.7719558505817818, 0.9806819464716613, 0.9818054735969601]
#
#
# file_id:  28416 .txt
# []
# []
#
#
# file_id:  28417 .txt
# ['start', 'Group financial highlights', 'Chairman’s statement', 'Group Chief Executive’s review']
# [0.8799227487841292, 0.7668812043360692, 0.9801581805792308, 0.9816447192511374]
#
#
# file_id:  28418 .txt
# ['Group financial highlights', 'Chairman’s statement', 'Group Chief Executive’s review']
# [0.7682592963335222, 0.980515463633042, 0.9814379944006194]
#
#
# file_id:  28419 .txt
# ['Financial highlights', 'Chairman’s statement', 'Group Chief Executive’s strategic review']
# [0.8802506848498343, 0.9811684366086055, 0.9402495728256578]
#
#
# file_id:  28421 .txt
# ['At a glance', 'Chairman’s statement', 'Group Chief Executive’s report']
# [0.9138433166613074, 0.9812002278343012, 0.9205733527354953]
#
#
# file_id:  28422 .txt
# ['Highlights', 'Chairman’s statement', 'Group Chief Executive’s report', 'Financial highlights']
# [0.9935393614017336, 0.9811653002899138, 0.9208373607880884, 0.8726335869579751]
#
#
# file_id:  28423 .txt
# ['Highlights', 'At a glance', 'Chairman’s statement', 'Group Chief Executive’s report', 'Financial highlights']
# [0.9933744317374181, 0.9107550097051879, 0.9806943288774994, 0.918778962236592, 0.8695316058532816]
#
#
# file_id:  28425 .txt
# ['start']
# [0.8771981614666142]
#
#
# file_id:  28427 .txt
# ['start', 'Chairman’s statement', 'Group Chief Executive’s report']
# [0.8780558662194122, 0.9807874958406557, 0.9163781771301456]
#
#
# file_id:  28433 .txt
# ['Chairman’s statement', 'Group Chief Executive’s report', 'At a glance']
# [0.9817377101126096, 0.9218782854525613, 0.9041595313814117]
#
#
# file_id:  28491 .txt
# ['Highlights', 'Chairman’s statement', 'Chief Executive Officer’s review']
# [0.9935764067162253, 0.9816396578022768, 0.9741959586013687]
#
#
# file_id:  28493 .txt
# ['start', 'Letter from the Chief Executive Offi cer']
# [0.8793586817442621, 0.9509144744776848]
#
#
# file_id:  28506 .txt
# ['start', 'Key highlights', 'Chairman’s statement', 'Chief Executive Officer’s statement']
# [0.876662361635277, 0.9000737536222018, 0.9810944012921897, 0.9653162185595949]
#
#
# file_id:  28508 .txt
# ['Highlights of the Year', 'At a Glance', 'Chairman’s Statement', 'Introduction from the Chairman', 'Senior Executives']
# [0.926292239554636, 0.9150230725248282, 0.9800385297591511, 0.7367852469553231, 0.6726267542075348]
#
#
# file_id:  28518 .txt
# ['Highlights', 'Chairman’s statement', 'Chief Executive’s report']
# [0.993451642812381, 0.9815839034254583, 0.9543828326602042]
#
#
# file_id:  28604 .txt
# ['Group at a glance', 'Chairman’s letter', 'Chief Executive’s Q&A']
# [0.8160700229840427, 0.83164494828624, 0.9964961838300845]
#
#
# file_id:  28618 .txt
# ['Highlights', 'Chairman’s statement', 'Rathbones at a glance', 'Chief executive’s statement']
# [0.9935673850366636, 0.9818498297194319, 0.9139505702614981, 0.9815177799842077]
#
#
# file_id:  28619 .txt
# ['Highlights', 'Chairman’s statement', 'Rathbones at a glance', 'Chief executive’s statement']
# [0.9935562338113378, 0.9817369531518527, 0.9135505465668569, 0.9814144378089541]
#
#
# file_id:  28620 .txt
# ['start', 'Chairman’s statement', 'Chief executive’s statement', 'Rathbones at a glance']
# [0.877154001010944, 0.9815935899040216, 0.9813093284389717, 0.9093358480336691]
#
#
# file_id:  28621 .txt
# ['start']
# [0.8877330861604694]
#
#
# file_id:  28622 .txt
# ['start']
# [0.8835797029499329]
#
#
# file_id:  28623 .txt
# ['Highlights of the year', 'Chairman’s statement', 'Chief Executive’s statement', 'Rathbones at a glance']
# [0.926335819878651, 0.9815096738279844, 0.9810803228863489, 0.9090205295263701]
#
#
# file_id:  28624 .txt
# ['Highlights of the year', 'Chairman’s statement', 'Chief Executive’s statement', 'Rathbones at a glance']
# [0.9262768427783784, 0.9816970882388646, 0.9809267477030316, 0.9018257004979042]
#
#
# file_id:  28625 .txt
# ['Highlights of the year', 'Chairman’s statement', 'Chief executive’s statement']
# [0.9263566260923153, 0.9817357914799738, 0.9810162634334855]
#
#
# file_id:  28626 .txt
# ['Highlights of the year', 'Chairman’s statement', 'Chief executive’s statement']
# [0.9261047538329906, 0.9819404964758222, 0.9810672383877237]
#
#
# file_id:  28627 .txt
# ['Highlights of the year', 'Chairman’s statement', 'Chief executive’s statement']
# [0.9259749756582857, 0.981361755326614, 0.9811222489759891]
#
#
# file_id:  28628 .txt
# ['Highlights of the year', 'Our business at a glance', 'Chairman’s statement', 'Chief executive’s review']
# [0.9261628094636992, 0.7314486698830281, 0.9809069419024323, 0.9925722479270548]
#
#
# file_id:  28629 .txt
# ['Results Highlights', 'Chairman’s Message', 'Chief Executive’s Report']
# [0.9194051843229298, 0.8440779787564471, 0.9542760453350254]
#
#
# file_id:  28653 .txt
# ['Highlights', 'Chairman’s Statement', 'Chief Executive’s Statement', 'Executive Committee', 'Chairman’s Statement on Corporate']
# [0.9934071092982238, 0.9808105982871862, 0.9794055794027967, 0.5300583818038774, 0.7691409921040621]
#
#
# file_id:  28657 .txt
# ['Chairman’s statement', 'Chief Executive Officer’s statement']
# [0.9817315792222556, 0.9665048360103412]
#
#
# file_id:  28658 .txt
# ['Chairman’s statement', 'Chief Executive Officer’s statement']
# [0.9816607390072423, 0.9663288115114815]
#
#
# file_id:  28680 .txt
# ['start', 'Chairman’s statement', 'Highlights']
# [0.8810215116086269, 0.9732771946455342, 0.9904482321429872]
#
#
# file_id:  28692 .txt
# ['Highlights', 'Group at a Glance', 'Chairman’s Statement', 'Chief Executive’s Statement']
# [0.9935775810946978, 0.8146238736523571, 0.981192936117108, 0.9802002622533396]
#
#
# file_id:  28695 .txt
# ['HIGHlIGHts', 'at a Glance', 'cHaIRman’s statement', 'cHIeF executIVe oFFIceR’s statement']
# [0.9935731248870403, 0.9141570110502711, 0.9815288353609568, 0.9662095509407165]
#
#
# file_id:  28712 .txt
# ['Chairman’s statement', 'Chief Executive’s review']
# [0.9817412585719707, 0.9928009456253499]
#
#
# file_id:  28717 .txt
# ['At a glance', 'Chairman’s statement']
# [0.913278855796272, 0.9814739425491149]
#
#
# file_id:  28718 .txt
# ['Highlights', 'Group at a Glance', 'Chairman’s Letter', "Chief Executive's Review", 'Q&A with Chief Executive', 'Chairman’s Letter']
# [0.9934212577021956, 0.810079196921458, 0.8151903671474953, 0.9919502068051668, 0.9957098462633382, 0.6723472626042908]
#
#
# file_id:  28719 .txt
# ['Highlights', 'At a glance', 'Chairman’s statement', 'Chief Executive’s review']
# [0.9935748695586093, 0.9128158669366548, 0.9812643318479533, 0.9928338345355192]
#
#
# file_id:  28720 .txt
# ['Our highlights', 'Chairman’s statement', 'Chief Executive Officer’s review']
# [0.9935800713697125, 0.9810163228441773, 0.9729438552162886]
#
#
# file_id:  28721 .txt
# ['cHAiRMAn’s st AteMent', 'cHieF eXecutiVe oFFiceR’s ReVieW']
# [0.7540660103805561, 0.9745632026955574]
#
#
# file_id:  28722 .txt
# ...
# [0.8833166455389452, 0.9813564571926034, 0.9928517834975338]
#
#
# file_id:  30559 .txt
# ['Highlights', 'Chairman’s statement', 'Chief executive of¢cer’s review']
# [0.9935394821192234, 0.9815385315122118, 0.9615317798131781]
#
#
# file_id:  30563 .txt
# ['Chairman’s statement', 'Group Chief Executive’s Q&A', 'Group Chief Executive’s review', 'Group at a glance', 'At a glance']
# [0.9817594975598384, 0.9857888198906622, 0.9827610550607618, 0.8061314580663651, 0.8245287133128065]
#
#
# file_id:  30575 .txt
# ['At a glance', 'Chairman’s statement', 'Chief Executive’s statement']
# [0.913802010847598, 0.9812129465616387, 0.9806622019878032]
#
#
# file_id:  30597 .txt
# ['Group highlights', 'Chairman’s statement']
# [0.9241581990767235, 0.9820120382585698]
#
#
# file_id:  30608 .txt
# ['Highlights', 'At a glance', 'Chairman’s statement', 'Chief Executive Officer’s statement']
# [0.9935714956587987, 0.913754477411067, 0.981569495343186, 0.9666303737260059]
#
#
# file_id:  30625 .txt
# ['Zoopla Property Group at a glance', 'Chairman’s statement', 'Chief Executive Officer’s statement', 'Our brands at a glance']
# [0.7666697180804043, 0.9812788513143512, 0.9660815705351103, 0.6937227000247009]
#
#
# file_id:  30626 .txt
# ['Highlights', 'At a glance', 'Chairman’s statement', 'Chief Executive Officer’s statement']
# [0.9935401309263373, 0.9126924467834971, 0.9811747337563418, 0.9655643907401916]
#
#
# file_id:  30627 .txt
# ['At a glance', 'Highlights', 'Chairman’s statement']
# [0.9139947165644533, 0.9935008999665093, 0.9813319116893732]
#
#
# file_id:  30639 .txt
# ['Group highlights', 'Chairman’s statement', 'Group Chief Executive’s review', 'A letter from our Chairman']
# [0.9236308219021311, 0.9816960051886906, 0.9826181734793433, 0.6823580077992851]
#
#
# file_id:  30641 .txt
# ['start', 'Highlights', 'Group Chairman’s Statement', 'Group Chief Executive’s Review']
# [0.8768853502494638, 0.9934156703589331, 0.9428229503882783, 0.9822837223243376]
#
#
# file_id:  30643 .txt
# ['2017 performance highlights', 'Chairman’s statement', 'Chief Executive’s review', 'Segmental highlights']
# [0.9194089741821513, 0.9818666362962067, 0.9926410712486428, 0.9570103420882804]
#
#
# file_id:  30645 .txt
# ['AT A GLANCE', 'CHIEF EXECUTIVE’S STATEMENT', 'CHAIRMAN’S THOUGHTS']
# [0.9137529137583436, 0.9802513255404761, 0.94873885322241]
#
#
# file_id:  30647 .txt
# ['start', 'Chairman’s statement', 'Chief executive’s statement', 'Q&A with the chief executive', 'Letter from our chairman', 'Letter from the chairman']
# [0.8771895614660891, 0.9796285234756933, 0.9791095662177597, 0.9959487038534807, 0.6788338816757896, 0.670727135216917]
#
#
# file_id:  30648 .txt
# ['2017 performance highlights', 'Chairman’s statement', 'Chief Executive’s review', 'Segmental highlights']
# [0.9194089741821513, 0.9818666362962067, 0.9926410712486428, 0.9570103420882804]
#
#
# file_id:  30650 .txt
# ['Financial Highlights', 'Group at a Glance', 'at a Glance', 'Chairman’s Statement', 'Chief Executive’s Statement', 'Executive and HSE Committees']
# [0.8821481244567552, 0.8144099405093801, 0.9114776223039933, 0.9811226685892575, 0.9804447059630922, 0.6904893795010997]
#
#
# file_id:  30653 .txt
# ['Our business at a glance', 'Chairman’s letter', 'Group Chief Executive’s', 'Our strategy at a glance', 'Chairman’s introduction']
# [0.7302089809548238, 0.8286239943942931, 0.9853229965396245, 0.7610728958741295, 0.6535896899271255]
#
#
# file_id:  30657 .txt
# ['start', 'At a glance', 'Chairman’s statement', 'Chief Executive’s statement', 'Chairman’s introduction']
# [0.8754384239535744, 0.9117932453570384, 0.9807061572607237, 0.9787413442321394, 0.5347793105790708]
#
#
# file_id:  30665 .txt
# ['Performance Highlights', 'Chairman’s Statement', 'Chief Executive’s Review', 'Chairman’s Introduction']
# [0.9197968956384052, 0.9814547816396035, 0.9913322617228244, 0.6715469417479016]
#
#
# file_id:  30679 .txt
# []
# []
#
#
# file_id:  30682 .txt
# ['Highlights', 'Chairman’s statement', 'Chief Executive Officer’s statement']
# [0.9935488976815886, 0.981316965410942, 0.9661032958960752]
#
#
# file_id:  30683 .txt
# ['start', 'AstraZeneca at a glance', 'Chairman’s Statement']
# [0.8759150900008091, 0.7019418978897107, 0.9805020286292229]
#
#
# file_id:  30685 .txt
# ['start', 'Chairman’s statement', 'Our business at a glance', 'Group Chief Executive Officer Q&A', 'Letter from the Chairman']
# [0.8773236086325845, 0.9814698916753752, 0.7211854249884923, 0.976092800054801, 0.669601258836688]
#
#
# file_id:  30686 .txt
# ['Financial highlights', 'Operating highlights', 'At a glance', 'Chairman’s statement', 'Chief Executive Officer’s statement']
# [0.882469634046078, 0.8902015621215066, 0.9135503014464941, 0.9812485435543606, 0.9661273465968652]
#
#
# file_id:  30687 .txt
# ['Our Group highlights', 'Chairman’s foreword', 'Chief Executive Officer’s foreword', 'Executive Team overview']
# [0.9241097694954774, 0.8320044925295229, 0.9831453481786987, 0.6093242632834456]
#
#
# file_id:  30689 .txt
# ['Coats at a glance', 'Chairman’s statement', 'Group Chief Executive’s', 'Chairman’s Introduction']
# [0.9131255920411112, 0.981550911590124, 0.9856722810226409, 0.6808282168718555]
#
#
# file_id:  30702 .txt
# ['Highlights', 'Group at a glance', 'Chairman’s statement', 'Chief Executive Officer’s review']
# [0.9934893952161604, 0.8136211835343009, 0.9813748378014697, 0.9740052305581192]
#
#
# file_id:  30706 .txt
# ['Financial highlights', 'Chief Executive’s report']
# [0.8830844340228056, 0.954777004319526]
#
#
# file_id:  30708 .txt
# ['Highlights', 'Letter from the Chairman', "Chief Executive's Review", 'Chairman’s introduction']
# [0.9935110746337388, 0.8198006112624378, 0.9927671580724161, 0.6172181225522702]
#
#
# file_id:  30710 .txt
# ['Group highlights', 'Chairman’s statement', 'Group Chief Executive’s review', 'A letter from our Chairman']
# [0.9236308219021311, 0.9816960051886906, 0.982616673369393, 0.6824773475985766]
#
#
# file_id:  30711 .txt
# ['start', 'Hunting at a glance', 'Chairman’s statement', 'Chief Executive’s statement']
# [0.877340073618112, 0.9127799699251677, 0.9812103826927013, 0.980700589361269]
#
#
# file_id:  30714 .txt
# ['Key highlights and outlook', 'Chairman’s Statement', 'Chief Executive’s Review 2017']
# [0.8080100656134412, 0.980668828996547, 0.9923421692041046]
#
#
# file_id:  30721 .txt
# ['start', 'Chief Executive’s review', 'Chairman’s statement']
# [0.8774377415065375, 0.9923478636597253, 0.9709248950542224]
#
#
# file_id:  30723 .txt
# ['Chairman’s statement', 'Chief Executive’s review']
# [0.9814342751656687, 0.9927142940025592]
#
#
# file_id:  30725 .txt
# ['Financial highlights', 'Group at a glance', 'Chairman’s statement', 'Chief Executive’s review', 'Q&A with the Chief Executive']
# [0.8830076956218061, 0.8152974830245271, 0.9814327450581384, 0.9926396224664514, 0.9963371822717598]
#
#
# file_id:  30727 .txt
# ['At a Glance', 'Chairman’s Letter', 'Chairman’s Introduction to']
# [0.913792922377895, 0.8291151797077595, 0.6586269415578141]
#
#
# file_id:  30731 .txt
# ['Schroders at a glance', 'Chairman’s statement', 'Group Chief Executive’s review']
# [0.9148927117443485, 0.9808458298151519, 0.9824401841259525]
#
#
# file_id:  30732 .txt
# ['start', 'Group at a glance', 'Q&A with the Chairman']
# [0.8776066383191258, 0.81356182922545, 0.9710341621948575]
#
#
# file_id:  30734 .txt
# ['Highlights', 'Chairman’s statement', 'At a glance global burden of disease', 'Chief Executive Officer’s statement', 'Our Executive Committee']
# [0.9935164222444732, 0.9815176672715916, 0.7046008596038618, 0.964653939752808, 0.5054295167821284]
#
#
# file_id:  30735 .txt
# ['start', 'Group at a Glance', 'Chairman’s Statement', 'Chief Executive Officer’s Statement']
# [0.8767617735513509, 0.8146459252380147, 0.9812162293436789, 0.9653683634956083]
#
#
# file_id:  30736 .txt
# ['Highlights', 'Chairman’s statement', 'Chief executive’s statement', 'Chairman’s statement']
# [0.9934625213179117, 0.9802143057557829, 0.9799104564314036, 0.964186653926238]
#
#
# file_id:  30742 .txt
# ['start', 'SDL at a Glance', 'Chairman’s Introduction', 'Chief Executive Officer’s Review', 'Chairman’s Introduction']
# [0.8804343197075776, 0.7760675427364924, 0.7270242794057088, 0.9717714517624797, 0.5881810074721028]
#
#
# file_id:  30743 .txt
# ['start']
# [0.8927016184555584]
#
#
# file_id:  30744 .txt
# ['Highlights', 'At a Glance', 'Chairman’s Statement', 'Chief Executive’s Review']
# [0.9935595464739941, 0.9132170595352667, 0.9808866577096003, 0.9926373302177892]
#
#
# file_id:  30745 .txt
# ['Highlights 2017', 'Chairman’s Statement', 'Group Chief Executive’s Review']
# [0.9935289684345947, 0.981791992198216, 0.9828042871620872]
#
#
# file_id:  30749 .txt
# ['Highlights', 'At a glance', 'Chairman’s Introduction']
# [0.9935598274669437, 0.913352222070916, 0.7447340157467182]
#
#
# file_id:  30750 .txt
# ['At a Glance', 'Chairman’s Statement', 'Chief Executive’s Statement', 'Highlights', 'Financial Highlights']
# [0.9136809523267023, 0.9813918835737742, 0.980985259908593, 0.9923475561745737, 0.794340129882817]
#
#
# file_id:  30753 .txt
# ['Gamma at a glance', 'Chairman’s statement', 'Chief Executive Officer’s review', 'Chairman’s introduction']
# [0.9123187029026835, 0.980571228821387, 0.9720475361036641, 0.633126314262665]
#
#
# file_id:  30755 .txt
# ['Chairman’s statement', 'Chief Executive’s review', 'Strategy at a glance', 'Chairman’s introduction']
# [0.9821475329445413, 0.9921692759951158, 0.7639524660775704, 0.6620496221154962]
#
#
# file_id:  30756 .txt
# ['Group at a Glance', 'Chairman’s Statement', 'Chief Executive’s Review']
# [0.8159070180728507, 0.9813718572365696, 0.9926642783734045]
#
#
# file_id:  30761 .txt
# ['RSA at a glance', 'Chairman’s statement', 'Group Chief Executive’s statement']
# [0.9130410405500184, 0.9814329609593068, 0.9585460673772904]
#
#
# file_id:  30771 .txt
# ['start', 'Group highlights', 'Group at a glance', 'Chairman’s statement', 'Chief Executive Officer’s review', 'Chairman’s introduction', 'Executive Committee']
# [0.8774308447458083, 0.9233899770720625, 0.8108639571585041, 0.9806367532431673, 0.9723381753169825, 0.6395010757125513, 0.5491888551308488]
#
#
# file_id:  30773 .txt
# ['Highlights', 'At a Glance', 'Chairman’s Statement', 'Chief Executive’s Statement']
# [0.9935264451579713, 0.9119408480472387, 0.9810860799944457, 0.9804229370338697]
#
#
# file_id:  30774 .txt
# ['Highlights', 'Chairman’s Statement', 'Chief Executive’s Statement', 'Executive Committee']
# [0.9935537879492898, 0.9807450326415356, 0.9797181625286233, 0.5044045452860938]
#
#
# file_id:  30775 .txt
# ['Financial highlights', 'Chairman’s statement', 'Chief Executive Officer’s review']
# [0.8809073728828037, 0.9813014259353814, 0.9720364274936508]
#
#
# file_id:  30776 .txt
# ['At a Glance', 'Chairman’s Statement', 'Chief Executive’s Statement']
# [0.9136629738780648, 0.9817713972930875, 0.9774307008539312]
#
#
# file_id:  30789 .txt
# ['Highlights', 'At a Glance', 'Chairman’s Statement', 'Chief Executive’s Review']
# [0.99355745880073, 0.9126584752040406, 0.981336910123219, 0.9927581284003064]
#
#
# file_id:  30829 .txt
# ['Chairman’s statement', 'Reignite Growth – 2017 highlights']
# [0.9818148611264697, 0.9638972477887036]
#
#
# file_id:  4000 .txt
# ['Our highlights', 'Chairmans statement', 'Chief Executives statement']
# [0.9934186945565808, 0.9804127676506845, 0.97770163961617]
#
#
# file_id:  4001 .txt
# ['At a glance', 'Chief Executives report']
# [0.9140365445115254, 0.9537624081367652]
#
#
# file_id:  4002 .txt
# ['Financial and Strategic Highlights', 'Chairmans Statement', 'Chief Executives Market and Operational Review']
# [0.6750364799997483, 0.9780837807660395, 0.867360161738479]
#
#
# file_id:  4003 .txt
# ['AT A GLANCE 4RISK']
# [0.8949157657462701]
#
#
# file_id:  4004 .txt
# ['start']
# [0.8762843530533364]
#
#
# file_id:  4005 .txt
# ['start']
# [0.8314782501430491]
#
#
# file_id:  4006 .txt
# ['Chief Executives statement and strategic review']
# [0.9440279798618256]
#
#
# file_id:  4007 .txt
# ['At a Glance 2 Governance at a Glance', 'Chief Executive Officers Statement 6 The Board']
# [0.5665847769147965, 0.9089491911280289]
#
#
# file_id:  4008 .txt
# ['start', 'Group Chief Executives review']
# [0.8782631939490503, 0.9824647888751437]
#
#
# file_id:  4009 .txt
# ['start', 'Chief Executives Review  4 Our Vapour Products  32 on Governance']
# [0.8780477003709696, 0.8873555722570209]
#
#
# file_id:  4010 .txt
# []
# []
#
#
# file_id:  4011 .txt
# ['Chief Executives statement 58 Leadership and oversight 130 Notes to the financial statements']
# [0.6299284076222951]
#
#
# file_id:  4012 .txt
# ['start']
# [0.8799065830235759]
#
#
# file_id:  4013 .txt
# ['Our investment case Officersreview70 Chairmans introduction incomestatement', 'Chairmans statement 36 Chief People Officers review togovernance 133 Earnings per share', 'Chief Executives review 40 Whitbread Inclusion Networks 72 Corporate governance134 Consolidated statement']
# [0.5759732459281721, 0.8991190427285697, 0.5839915266982069]
#
#
# file_id:  4014 .txt
# ['Chief Executive Officers report']
# [0.6196230242985917]
#
#
# file_id:  4015 .txt
# ['start']
# [0.8822122875768985]
#
#
# file_id:  4016 .txt
# ['start']
# [0.8791459996390695]
#
#
# file_id:  4017 .txt
# ['Chief Executive Officers review 120 Leadership and purpose']
# [0.9539268393222483]
#
#
# file_id:  4018 .txt
# ['C hief Executives strategic review', 'Executive team']
# [0.5512044363470621, 0.5058560606532131]
#
#
# file_id:  4019 .txt
# ['Chief Executive’s report']
# [0.9535121287337617]
#
#
# file_id:  4020 .txt
# []
# []
#
#
# file_id:  4021 .txt
# ['Financial Highlights Financial Report']
# [0.5021808910003832]
#
#
# file_id:  4022 .txt
# ['start', 'Chief Executives review 12 Looking forward by segment']
# [0.8777984756231267, 0.9214981198310338]
#
#
# file_id:  4023 .txt
# []
# []
#
#
# file_id:  4024 .txt
# ['start', 'Performance highlights 1 Chairmans governance statement']
# [0.879801435032611, 0.7003115823775617]
#
#
# file_id:  4025 .txt
# ['start', 'Chief Executives review']
# [0.878379105329469, 0.9925486871709086]
#
#
# file_id:  4026 .txt
# []
# []
#
#
# file_id:  4027 .txt
# ['Highlights', 'Chief Executive Officers report', 'RELX senior executives']
# [0.9935310900556648, 0.932197845743887, 0.517233480261267]
#
#
# file_id:  4028 .txt
# ['Chairmans Statement']
# [0.9812440670500031]
#
#
# file_id:  4029 .txt
# ['start']
# [0.8774390560464059]
#
#
# file_id:  4030 .txt
# ['Chairmans Statement', 'Financial Highlights']
# [0.9815854213099163, 0.7750419646668661]
#
#
# file_id:  4031 .txt
# ['At a glance', 'Chairmans statement', 'Chief Executive Officers statement']
# [0.9134594269433378, 0.9808818549130465, 0.9651592975185701]
#
#
# file_id:  4032 .txt
# ['Company Highlights', 'Chairmans Statement']
# [0.8220771075108483, 0.9820334977870253]
#
#
# file_id:  4033 .txt
# ['Chairman’s statement', 'Chief Executive’s statement']
# [0.9815879043566264, 0.9805649614586318]
#
#
# file_id:  4034 .txt
# ['Executive Committee']
# [0.5274022610818598]
#
#
# file_id:  4035 .txt
# ['Operational highlights', 'Chief Executives review', 'At a glance']
# [0.8886136110307067, 0.9927706858252189, 0.8274268561349856]
#
#
# file_id:  4036 .txt
# ['Chairman’s statement', 'Chief Executive’s review']
# [0.9813450525936528, 0.9930984985957677]
#
#
# file_id:  4037 .txt
# ['Chairman’s Statement', 'Chief Executive’s Review']
# [0.9816961420689624, 0.993660440041781]
#
#
# file_id:  4038 .txt
# []
# []
#
#
# file_id:  4039 .txt
# ['Diploma at a Glance', 'Highlights']
# [0.7924900213778995, 0.9934565519165013]
#
#
# file_id:  4040 .txt
# ['Chairmans Statement']
# [0.9818885018687457]
#
#
# file_id:  4041 .txt
# ['Chairmans statement', 'Chief Executive Officers review']
# [0.981613798115946, 0.9746783138438535]
#
#
# file_id:  4042 .txt
# ['Group Highlights', 'Chairmans Statement', 'Group Chief Executives Statement']
# [0.9216202753871323, 0.9811079780500532, 0.9604425937351143]
#
#
# file_id:  4043 .txt
# ['start', 'Chairmans Statement 6', 'The Investment Portfolio At a Glance 12', 'Top 10 Assets Operational Highlights 26', 'Sustainability Highlights 30']
# [0.8790526546247382, 0.9806097735428416, 0.6346618298859347, 0.7738454467866464, 0.9695473229135764]
#
#
# file_id:  4044 .txt
# ['At a glance']
# [0.9097199977709527]
#
#
# file_id:  4046 .txt
# ['Chairmans introduction', 'Chief Executives Review']
# [0.7385038406861059, 0.9926453170354624]
#
#
# file_id:  4047 .txt
# ['At a glance', 'Highlights']
# [0.9130609052832332, 0.9934322133525626]
#
#
# file_id:  4048 .txt
# ['Chairmans Statement 74 Key Representatives of the Manager']
# [0.9436819849248792]
#
#
# file_id:  4049 .txt
# ['Group Chief Executives review']
# [0.9819902541507369]
